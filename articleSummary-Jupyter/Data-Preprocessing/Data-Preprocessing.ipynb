# %%
# _*_ coding: utf-8 _*_
import re
import nltk
import os
import csv
import math
import pandas as pd
import numpy as np
from glob import iglob
from functools import reduce
from konlpy.tag import Komoran
from gensim.summarization.summarizer import summarize


nltk.download('punkt')

import import_ipynb
from CommonModule.Handle_Dir import mkdir_p, del_folder
from CommonModule.ArticleHandler import Article, ArticleReader
from CommonModule.TextPreprocessor import TextPreprocessor
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
BASE_DIR = "/data/ksb/TestDir/articles"
ORIGIN_PATH = os.path.join(BASE_DIR,"Origin-Data")
PREPROCESSED_PATH = os.path.join(BASE_DIR,"Preprocessed-Data")
SUMMARY_PATH = os.path.join(BASE_DIR,"Summary-Data")
SUMMARY_PREPROCESSED_PATH = os.path.join(BASE_DIR,"Summary-Preprocessed-Data")
SWORDS_PATH = os.path.join(BASE_DIR, "StopWordList.txt")

# %%
del_folder(PREPROCESSED_PATH)
mkdir_p(PREPROCESSED_PATH)

# %%
del_folder(SUMMARY_PATH)
mkdir_p(SUMMARY_PATH)

# %%
del_folder(SUMMARY_PREPROCESSED_PATH)
mkdir_p(SUMMARY_PREPROCESSED_PATH)

# %%
preprocessor = TextPreprocessor()
preprocessor.loadSwords(SWORDS_PATH)
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼\t어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다\t하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영']

# %%
MAX_COUNT = 250
MIN_COUNT = 10

get_token_count = lambda conts : reduce(lambda x, y: x + y, [len(x.split()) for x in conts])

# %%
def split_by_max_token(sents):
    token_lens = [len(x.split()) for x in sents]
    sum = 0

    for idx, length in enumerate(token_lens):
        if sum + length > MAX_COUNT : 
            return idx, sents[:idx]
            break
        sum += length

    return len(sents), sents

# %%
def saveCSVFile(baseDir, media, article_dist):
    save_path = os.path.join(baseDir, media) + ".csv"

    article_dist.to_csv(save_path, mode='w', header=False)

# %%
def get_media_name(filepath):
    filename = filepath.split(os.sep)[-1]
    return filename.split(".")[0]

# %%
def is_small_text(lines):
    if not lines : return True
    return get_token_count(lines) < MIN_COUNT

# %%
if __name__ == '__main__':
    
    for idx, media_path in enumerate(iglob(os.path.join(ORIGIN_PATH, '**.csv'), recursive=False)):

        media_name = get_media_name(media_path)
        preprocessed_path = os.path.join(PREPROCESSED_PATH, media_name) + ".csv"
        print(media_name, preprocessed_path)
        
        f = open(media_path, 'r', newline="\n", encoding="utf-8")

        processed_dist = pd.DataFrame(columns=['Title', 'Contents'])
        summary_dist = pd.DataFrame(columns=['Title', 'Contents'])
        summary_proc_dist = pd.DataFrame(columns=['Title', 'Contents'])

        for [title, contents] in csv.reader(f):
            article = Article(title, media_name, contents.split("\t"))
            
            try:
                contents = list(article.readContent())

                clean_conts = preprocessor.del_personal_info(contents, media_name)
                clean_conts = preprocessor.cleanLines(clean_conts)
                clean_title = preprocessor.cleanLine(article.title)

                split_idx, clean_conts = split_by_max_token(clean_conts)
                split_conts = contents[:split_idx]

                if is_small_text(clean_conts): continue

                # Article Summary
                conts_line = " ".join(split_conts)
                summary_lines = summarize(conts_line, ratio=0.2, split=True)
                    
                summary= {'Title' : article.title, 'Contents' : '\t'.join(summary_lines) }
                summary_dist = summary_dist.append(summary, ignore_index=True)
                    
                # Article Preprocessed Summary
                summary_proc_list = preprocessor.del_personal_info(summary_lines, media_name)
                summary_proc_list = preprocessor.cleanLines(summary_proc_list)
                    
                summary_proc= {'Title' : clean_title, 'Contents' : '\t'.join(summary_proc_list) }
                summary_proc_dist = summary_proc_dist.append(summary_proc, ignore_index=True)
                    
                # Preprocessed Article
                proc = {'Title' : clean_title, 'Contents' : '\t'.join(clean_conts)}
                processed_dist = processed_dist.append(proc, ignore_index=True)
                    
            except Exception as err:
                print(err)
                print("Drop Article : {title}".format(title=article.title))
                pass
                
        saveCSVFile(PREPROCESSED_PATH, media_name, processed_dist)
        saveCSVFile(SUMMARY_PREPROCESSED_PATH, media_name, summary_proc_dist)
        saveCSVFile(SUMMARY_PATH, media_name, summary_dist)
        f.close()
# Out:
# 세계일보 /data/ksb/TestDir/articles/Preprocessed-Data/세계일보.csv
# KBS /data/ksb/TestDir/articles/Preprocessed-Data/KBS.csv
# input must have more than one sentence
# Drop Article : 2, [사사건건 플러스] 동급생 간 성폭력 피해자 숨져…사건 전말은?
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] ‘중대재해’ 처벌…정치권 합종연횡?
# input must have more than one sentence
# Drop Article : 0, [여의도사사건건]‘공무원 피격’ 권성동 “北에 구조 요청했어야” 정청래 “남북관계 회복돼야”
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] 윤석열 정직 2개월…“비위 엄중”·“비상식적”
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] 21대 국회 첫 국정감사…‘공무원 피살’·‘추미애 아들’ 등 쟁점
# input must have more than one sentence
# Drop Article : 0, [사사건건 플러스] 사망자 유족 폭력 자제 호소 분노 잦아들까
# input must have more than one sentence
# Drop Article : 1, [사사건건 플러스] 사망자 유족 폭력 자제 호소 분노 잦아들까
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] 국민의힘 권성동 “개천절 집회 자제해야”
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] 18개 상임위원장 모두 민주당이? 그 결과는…
# input must have more than one sentence
# Drop Article : 1, [사사건건 플러스]② 코로나19 신규 확진자 629명…서울시, 내일부터 2주간 ‘9시 이후 멈춤’
# input must have more than one sentence
# Drop Article : 0, [여의도 사사건건] 강훈식 “김봉현 입에 널뛰는 여의도 부끄러워”
# input must have more than one sentence
# Drop Article : 0, [사사건건] 권성동 “필리버스터 김기현 다음 주자로…공수처법 부당성 호소”
# input must have more than one sentence
# Drop Article : 0, [사사건건 플러스] ‘이태원 클럽’ 관련 확진자 총 86명…“적극검사 협조 부탁”
# input must have more than one sentence
# Drop Article : 0, [사사건건] 권성동 “권력형 게이트” vs 정청래 “카더라 게이트”…라임·옵티머스 무엇?
# input must have more than one sentence
# Drop Article : 0, [사사건건] 강훈식 “마지막까지 여야 합의해 공수처장 후보 내는 게 바람직”
# 노컷뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/노컷뉴스.csv
# input must have more than one sentence
# Drop Article : 0, [속보]사랑제일교회발 누적 978명…광화문 집회 관련 294명 감염
# input must have more than one sentence
# Drop Article : 1, 운흥동 안동역 역사속으로…송현동 시대 17일 개막
# input must have more than one sentence
# Drop Article : 0, 지방분권 앞서 울산공무원들 역량 강화해야
# input must have more than one sentence
# Drop Article : 0, 이념의 대립에 희생된 울산 독립운동가 ‘학암 이관술’
# 뉴스1 /data/ksb/TestDir/articles/Preprocessed-Data/뉴스1.csv
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 대전·충남(19일, 월)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 대전·충남(10일, 월)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 정치·정부(8일, 목)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요일정] 정치·정부(8일, 목)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 전북(6일, 목)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 정치·정부 (22일, 화)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요일정] 정치·정부 (22일, 화)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 강원(8일, 수)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요 일정] 강원(8일, 수)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 울산(2일, 수)
# input must have more than one sentence
# Drop Article : 0, [일지]"부하직원 성추행" 오거돈 전 부산시장 자진사퇴에서 검찰 송치까지
# input must have more than one sentence
# Drop Article : 1, [일지]"부하직원 성추행" 오거돈 전 부산시장 자진사퇴에서 검찰 송치까지
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 대전·충남(22일, 화)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 강원(4일, 월)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 대전·충남(16일, 금)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 강원(22일, 수)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요 일정] 강원(22일, 수)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 정치·정부 (21일, 금)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 전북(18일, 수)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요일정] 전북(18일, 수)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 인천, 경기 부천·김포(21일, 수)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정]정치·정부 (2일, 금)
# input must have more than one sentence
# Drop Article : 1, [오늘의 주요일정]정치·정부 (2일, 금)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요 일정] 경기(16일, 목)
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정] 대전·충남(21일, 수)
# 연합뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/연합뉴스.csv
# 중앙일보 /data/ksb/TestDir/articles/Preprocessed-Data/중앙일보.csv
# 뉴시스 /data/ksb/TestDir/articles/Preprocessed-Data/뉴시스.csv
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정]제주(7월7일 화요일)
# input must have more than one sentence
# Drop Article : 7, 책 향기 따라 걸어보자…6월의 걷기여행길
# input must have more than one sentence
# Drop Article : 0, [오늘의 주요일정]정치(10월8일 목요일)
# input must have more than one sentence
# Drop Article : 1, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 2, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 3, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 4, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 5, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 7, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 8, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 9, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 10, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 11, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 12, [일지]김학의, 법무차관 임명부터 2심 실형까지
# input must have more than one sentence
# Drop Article : 13, [일지]김학의, 법무차관 임명부터 2심 실형까지
# EPA연합뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/EPA연합뉴스.csv
# input must have more than one sentence
# Drop Article : 0, FRANCE CYCLING TOUR DE FRANCE 2020
# input must have more than one sentence
# Drop Article : 0, (FILE) BOEING 737-800
# input must have more than one sentence
# Drop Article : 0, PAKISTAN PROTEST RAPE
# input must have more than one sentence
# Drop Article : 0, (FILE) MOROCCO DIPLOMACY LIBYA
# JTBC /data/ksb/TestDir/articles/Preprocessed-Data/JTBC.csv
# input must have more than one sentence
# Drop Article : 0, 확산세 계속…신천지 전수조사 마무리 시점에 변곡점?
# MBC /data/ksb/TestDir/articles/Preprocessed-Data/MBC.csv
# input must have more than one sentence
# Drop Article : 0, [이슈 완전정복] 국경봉쇄 속출…전세기로 교민 귀국
# input must have more than one sentence
# Drop Article : 4, "코로나 공포" 부추기는 가짜뉴스…엄벌한다더니
# input must have more than one sentence
# Drop Article : 0, [정치 와호장룡] 민주당 의원 제명…비례정당에 파견
# input must have more than one sentence
# Drop Article : 0, [이슈 완전정복] 방치 후 사망 자녀 2명 암매장… 20대 부부 구속
# MBC연예 /data/ksb/TestDir/articles/Preprocessed-Data/MBC연예.csv
# MBN /data/ksb/TestDir/articles/Preprocessed-Data/MBN.csv
# input must have more than one sentence
# Drop Article : 1, 부산에서 감염원 알 수 없는 10대 확진
# input must have more than one sentence
# Drop Article : 0, MBN 뉴스파이터-서울시, 46억 원 소송에…사랑제일교회 측 "패악질"
# input must have more than one sentence
# Drop Article : 1, "악마는 디테일에"…문 대통령, 꼼꼼한 검찰 개혁 주문
# input must have more than one sentence
# Drop Article : 1, 자가 격리 기간 절도범, 격리 시설서 또 도주하다 구속
# input must have more than one sentence
# Drop Article : 1, 문 대통령 "정국 혼란 죄송…공수처 출범 희망"
# MK스포츠 /data/ksb/TestDir/articles/Preprocessed-Data/MK스포츠.csv
# enews24 /data/ksb/TestDir/articles/Preprocessed-Data/enews24.csv
# 강원일보 /data/ksb/TestDir/articles/Preprocessed-Data/강원일보.csv
# input must have more than one sentence
# Drop Article : 0, 민주당 원경환 전 청장 `태횡영평정" 단수 공천
# 게임메카 /data/ksb/TestDir/articles/Preprocessed-Data/게임메카.csv
# 경향신문 /data/ksb/TestDir/articles/Preprocessed-Data/경향신문.csv
# 국민일보 /data/ksb/TestDir/articles/Preprocessed-Data/국민일보.csv
# 국회 /data/ksb/TestDir/articles/Preprocessed-Data/국회.csv
# 엑스포츠뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/엑스포츠뉴스.csv
# 여성신문 /data/ksb/TestDir/articles/Preprocessed-Data/여성신문.csv
# 연합뉴스TV /data/ksb/TestDir/articles/Preprocessed-Data/연합뉴스TV.csv
# 오마이뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/오마이뉴스.csv
# input must have more than one sentence
# Drop Article : 12, 열네살 때 월남, 열일곱 때 전쟁... 그의 기구한 사연
# input must have more than one sentence
# Drop Article : 27, 부산대에 새겨진 신영복 글씨의 의미
# 월간 산 /data/ksb/TestDir/articles/Preprocessed-Data/월간 산.csv
# 이데일리 /data/ksb/TestDir/articles/Preprocessed-Data/이데일리.csv
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리 신문]코로나 뚫고…부동산·주식 이어 M&A 큰장 선다
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리 신문]코로나 뚫고…부동산·주식 이어 M&A 큰장 선다
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리 신문]코로나 뚫고…부동산·주식 이어 M&A 큰장 선다
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리 신문]코로나 뚫고…부동산·주식 이어 M&A 큰장 선다
# input must have more than one sentence
# Drop Article : 10, [미리보는 이데일리신문] 11년 만에 또 생사기로, 쌍용차 법정관리 신청
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리 신문]극단적 정쟁에 막혀… 청년정치 설 땅이 없다
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리 신문]극단적 정쟁에 막혀… 청년정치 설 땅이 없다
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리 신문]극단적 정쟁에 막혀… 청년정치 설 땅이 없다
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리 신문]극단적 정쟁에 막혀… 청년정치 설 땅이 없다
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리 신문]극단적 정쟁에 막혀… 청년정치 설 땅이 없다
# input must have more than one sentence
# Drop Article : 1, [오늘의 국감일정]‘독감백신 상온노출’ 신성약품 대표 증인 출석
# input must have more than one sentence
# Drop Article : 1, 이데일리 "내일의 경제일정"-5월 한은 금융통화위원회
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리신문]4인가족 중심 인구정책 ‘인구쇼크’ 못 막아
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리신문]4인가족 중심 인구정책 ‘인구쇼크’ 못 막아
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]4인가족 중심 인구정책 ‘인구쇼크’ 못 막아
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]4인가족 중심 인구정책 ‘인구쇼크’ 못 막아
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리신문]4인가족 중심 인구정책 ‘인구쇼크’ 못 막아
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리신문]美 금융위기급 대응에도…머뭇거린 한은
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]美 금융위기급 대응에도…머뭇거린 한은
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리신문]美 금융위기급 대응에도…머뭇거린 한은
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]美 금융위기급 대응에도…머뭇거린 한은
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리신문]美 금융위기급 대응에도…머뭇거린 한은
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리 신문]최악 부채 공기업들 흥청망청 경영 여전
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리 신문]최악 부채 공기업들 흥청망청 경영 여전
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리 신문]최악 부채 공기업들 흥청망청 경영 여전
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리 신문]최악 부채 공기업들 흥청망청 경영 여전
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리 신문]최악 부채 공기업들 흥청망청 경영 여전
# input must have more than one sentence
# Drop Article : 1, 이데일리 "내일의 경제일정"-공적마스크 구매량 1인당 3매로 확대
# input must have more than one sentence
# Drop Article : 1, [내일의 국감일정]금융당국 부르는 정무위…"라임·옵티머스" 총공세
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리신문]강남에 몰린 재건축…집값 격차 더 벌렸다
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리신문]강남에 몰린 재건축…집값 격차 더 벌렸다
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]강남에 몰린 재건축…집값 격차 더 벌렸다
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리신문]강남에 몰린 재건축…집값 격차 더 벌렸다
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]강남에 몰린 재건축…집값 격차 더 벌렸다
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리신문]당정 ‘수용성’ 규제 갈팡질팡…주택시장 혼란 커져
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]당정 ‘수용성’ 규제 갈팡질팡…주택시장 혼란 커져
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리신문]당정 ‘수용성’ 규제 갈팡질팡…주택시장 혼란 커져
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]당정 ‘수용성’ 규제 갈팡질팡…주택시장 혼란 커져
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리 신문]‘혈세 원금보장’…뉴딜펀드 첫발부터 논란
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리 신문]‘혈세 원금보장’…뉴딜펀드 첫발부터 논란
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리 신문]‘혈세 원금보장’…뉴딜펀드 첫발부터 논란
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리 신문]‘혈세 원금보장’…뉴딜펀드 첫발부터 논란
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리신문]지자체 기본소득 홀릭…복지제도 판 뒤집나
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리신문]지자체 기본소득 홀릭…복지제도 판 뒤집나
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]지자체 기본소득 홀릭…복지제도 판 뒤집나
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리신문]지자체 기본소득 홀릭…복지제도 판 뒤집나
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]지자체 기본소득 홀릭…복지제도 판 뒤집나
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 3, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 4, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리신문]특고 대량해고 우려에 고용보험 확대 삐끗
# input must have more than one sentence
# Drop Article : 9, [미리보는 이데일리 신문]한국판 양적완화 시동…한은, RP 무제한 매입
# input must have more than one sentence
# Drop Article : 1, [미리보는 이데일리 신문]尹 징계, 秋 사의…정국 혼란 분수령
# input must have more than one sentence
# Drop Article : 2, [미리보는 이데일리 신문]尹 징계, 秋 사의…정국 혼란 분수령
# input must have more than one sentence
# Drop Article : 5, [미리보는 이데일리 신문]尹 징계, 秋 사의…정국 혼란 분수령
# input must have more than one sentence
# Drop Article : 6, [미리보는 이데일리 신문]尹 징계, 秋 사의…정국 혼란 분수령
# 이코노미스트 /data/ksb/TestDir/articles/Preprocessed-Data/이코노미스트.csv
# 일간스포츠 /data/ksb/TestDir/articles/Preprocessed-Data/일간스포츠.csv
# 일다 /data/ksb/TestDir/articles/Preprocessed-Data/일다.csv
# 전자신문 /data/ksb/TestDir/articles/Preprocessed-Data/전자신문.csv
# 정의당 /data/ksb/TestDir/articles/Preprocessed-Data/정의당.csv
# 정책브리핑 /data/ksb/TestDir/articles/Preprocessed-Data/정책브리핑.csv
# 주간조선 /data/ksb/TestDir/articles/Preprocessed-Data/주간조선.csv
# input must have more than one sentence
# Drop Article : 8, [부동산] 주택거래허가제는 이미 시행 중이다
# 텐아시아 /data/ksb/TestDir/articles/Preprocessed-Data/텐아시아.csv
# 파이낸셜뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/파이낸셜뉴스.csv
# 포모스 /data/ksb/TestDir/articles/Preprocessed-Data/포모스.csv
# 프레시안 /data/ksb/TestDir/articles/Preprocessed-Data/프레시안.csv
# input must have more than one sentence
# Drop Article : 20, US, "언유나이티드 스테이츠"...분열된 제국의 다음 선택은?
# 한겨레 /data/ksb/TestDir/articles/Preprocessed-Data/한겨레.csv
# input must have more than one sentence
# Drop Article : 3, [초단편소설,들 14] 상자
# 한겨레21 /data/ksb/TestDir/articles/Preprocessed-Data/한겨레21.csv
# 한경비즈니스 /data/ksb/TestDir/articles/Preprocessed-Data/한경비즈니스.csv
# 한국경제 /data/ksb/TestDir/articles/Preprocessed-Data/한국경제.csv
# 한국경제TV /data/ksb/TestDir/articles/Preprocessed-Data/한국경제TV.csv
# input must have more than one sentence
# Drop Article : 11, 베트남, 1분기 GDP성장률 3.8%‥부동산 온라인 판매 30%↑/글로벌증시 급등락 변동 지속 - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 17, 베트남, 1분기 GDP성장률 3.8%‥부동산 온라인 판매 30%↑/글로벌증시 급등락 변동 지속 - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 18, 베트남, 1분기 GDP성장률 3.8%‥부동산 온라인 판매 30%↑/글로벌증시 급등락 변동 지속 - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 13, 베트남, 증시 19년만에 최대폭 하락‥경제자유지수 23계단 상승/美·유럽 증시 일제히 하락 - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 14, 베트남, 사업규제 완화 FDI "러브콜"‥관광 경기부양 "시동"‥4월 수출 전년비 3.5%↓/美 증시·유가 동반상승‥美中 반도체 신냉전- <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 7, 베트남, 성장률 5% 경제회복 총력 선언‥공급부족 부동산 "들썩"‥원격의료 강화/美 체감실업률 20%대‥美·유럽 증시는 강세 - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 11, 베트남, 쌀 수출승인‥호찌민-껀터 고속도로 건설승인‥비트코인 금지 재확인/IMF "대공황이후 최악, 170개국 올해 역성장" - <KVINA 한줄뉴스>
# input must have more than one sentence
# Drop Article : 16, 베트남, 쌀 수출승인‥호찌민-껀터 고속도로 건설승인‥비트코인 금지 재확인/IMF "대공황이후 최악, 170개국 올해 역성장" - <KVINA 한줄뉴스>
# 한국일보 /data/ksb/TestDir/articles/Preprocessed-Data/한국일보.csv
# input must have more than one sentence
# Drop Article : 0, [인사] 해양수산부 외
# 헤럴드POP /data/ksb/TestDir/articles/Preprocessed-Data/헤럴드POP.csv
# 헤럴드경제 /data/ksb/TestDir/articles/Preprocessed-Data/헤럴드경제.csv
# 헬스조선 /data/ksb/TestDir/articles/Preprocessed-Data/헬스조선.csv
# 뉴스엔 /data/ksb/TestDir/articles/Preprocessed-Data/뉴스엔.csv
# 뉴스타파 /data/ksb/TestDir/articles/Preprocessed-Data/뉴스타파.csv
# 더팩트 /data/ksb/TestDir/articles/Preprocessed-Data/더팩트.csv
# 데일리e스포츠 /data/ksb/TestDir/articles/Preprocessed-Data/데일리e스포츠.csv
# 데일리안 /data/ksb/TestDir/articles/Preprocessed-Data/데일리안.csv
# 동아사이언스 /data/ksb/TestDir/articles/Preprocessed-Data/동아사이언스.csv
# 동아일보 /data/ksb/TestDir/articles/Preprocessed-Data/동아일보.csv
# input must have more than one sentence
# Drop Article : 1, 현대차, 운전 연수 앱 출시… 검증 강사-초보자 연결
# 디지털데일리 /data/ksb/TestDir/articles/Preprocessed-Data/디지털데일리.csv
# 디지털타임스 /data/ksb/TestDir/articles/Preprocessed-Data/디지털타임스.csv
# 마이데일리 /data/ksb/TestDir/articles/Preprocessed-Data/마이데일리.csv
# 매경이코노미 /data/ksb/TestDir/articles/Preprocessed-Data/매경이코노미.csv
# 씨네21 /data/ksb/TestDir/articles/Preprocessed-Data/씨네21.csv
# 아시아경제 /data/ksb/TestDir/articles/Preprocessed-Data/아시아경제.csv
# 아이뉴스24 /data/ksb/TestDir/articles/Preprocessed-Data/아이뉴스24.csv
# 앳스타일 /data/ksb/TestDir/articles/Preprocessed-Data/앳스타일.csv
# 매일경제 /data/ksb/TestDir/articles/Preprocessed-Data/매일경제.csv
# input must have more than one sentence
# Drop Article : 8, 영구미제로 남은 O. J. 심슨 사건을 아시나요?
# 매일신문 /data/ksb/TestDir/articles/Preprocessed-Data/매일신문.csv
# input must have more than one sentence
# Drop Article : 4, 대구경북의 미래, 행정통합에서 길을 찾다
# input must have more than one sentence
# Drop Article : 2, 대구시 "2주간 유흥시설 내 집합금지 행정명령 발동"(전문)
# 머니S /data/ksb/TestDir/articles/Preprocessed-Data/머니S.csv
# 머니투데이 /data/ksb/TestDir/articles/Preprocessed-Data/머니투데이.csv
# input must have more than one sentence
# Drop Article : 1, 경기도, 20일부터 수원역에 불공정 행위 도민신고센터 운영
# 문화일보 /data/ksb/TestDir/articles/Preprocessed-Data/문화일보.csv
# 미디어오늘 /data/ksb/TestDir/articles/Preprocessed-Data/미디어오늘.csv
# 부산일보 /data/ksb/TestDir/articles/Preprocessed-Data/부산일보.csv
# 블로터 /data/ksb/TestDir/articles/Preprocessed-Data/블로터.csv
# 서울경제 /data/ksb/TestDir/articles/Preprocessed-Data/서울경제.csv
# 참세상 /data/ksb/TestDir/articles/Preprocessed-Data/참세상.csv
# 채널A /data/ksb/TestDir/articles/Preprocessed-Data/채널A.csv
# 코리아중앙데일리 /data/ksb/TestDir/articles/Preprocessed-Data/코리아중앙데일리.csv
# 코리아헤럴드 /data/ksb/TestDir/articles/Preprocessed-Data/코리아헤럴드.csv
# 코메디닷컴 /data/ksb/TestDir/articles/Preprocessed-Data/코메디닷컴.csv
# 중앙SUNDAY /data/ksb/TestDir/articles/Preprocessed-Data/중앙SUNDAY.csv
# 조선비즈 /data/ksb/TestDir/articles/Preprocessed-Data/조선비즈.csv
# 조선일보 /data/ksb/TestDir/articles/Preprocessed-Data/조선일보.csv
# input must have more than one sentence
# Drop Article : 5, [윤희영의 News English] 중도층 유권자에 대한 오해와 진실
# input must have more than one sentence
# Drop Article : 0, [인사] 산업통상자원부 외
# 조세일보 /data/ksb/TestDir/articles/Preprocessed-Data/조세일보.csv
# 주간경향 /data/ksb/TestDir/articles/Preprocessed-Data/주간경향.csv
# 주간동아 /data/ksb/TestDir/articles/Preprocessed-Data/주간동아.csv
# 신동아 /data/ksb/TestDir/articles/Preprocessed-Data/신동아.csv
# AP연합뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/AP연합뉴스.csv
# YTN /data/ksb/TestDir/articles/Preprocessed-Data/YTN.csv
# input must have more than one sentence
# Drop Article : 1, [세상만사] "두바이 제트맨" 빈스 레페, 사막 훈련 중 사망
# input must have more than one sentence
# Drop Article : 0, 서기호"공수처장 임명동의 2/3이면 엄청난 것", 조영달"절차적 정당성이 더 중요해"
# input must have more than one sentence
# Drop Article : 0, [세상만사] "의사당 난입에 부실대응"... 비판받는 美 의회 경찰
# input must have more than one sentence
# Drop Article : 2, [세상만사] "의사당 난입에 부실대응"... 비판받는 美 의회 경찰
# input must have more than one sentence
# Drop Article : 0, [노영희의출발새아침] 故박원순, 양향자 "애도까지 정쟁" 박수영 "세금 써서 장례 맞나"
# input must have more than one sentence
# Drop Article : 0, [황보선의출발새아침]초선열전"대통령 만나고 싶다고 만날 수 있는 사람?"
# 서울신문 /data/ksb/TestDir/articles/Preprocessed-Data/서울신문.csv
# 스타뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/스타뉴스.csv
# 스포츠경향 /data/ksb/TestDir/articles/Preprocessed-Data/스포츠경향.csv
# 스포츠동아 /data/ksb/TestDir/articles/Preprocessed-Data/스포츠동아.csv
# 스포츠서울 /data/ksb/TestDir/articles/Preprocessed-Data/스포츠서울.csv
# 스포츠월드 /data/ksb/TestDir/articles/Preprocessed-Data/스포츠월드.csv
# 스포츠조선 /data/ksb/TestDir/articles/Preprocessed-Data/스포츠조선.csv
# input must have more than one sentence
# Drop Article : 5, 초여름, 책 향기 따라 걸어 볼까?
# 스포티비뉴스 /data/ksb/TestDir/articles/Preprocessed-Data/스포티비뉴스.csv
# 시사IN /data/ksb/TestDir/articles/Preprocessed-Data/시사IN.csv
# 시사저널 /data/ksb/TestDir/articles/Preprocessed-Data/시사저널.csv
# OSEN /data/ksb/TestDir/articles/Preprocessed-Data/OSEN.csv
# SBS Biz /data/ksb/TestDir/articles/Preprocessed-Data/SBS Biz.csv
# input must have more than one sentence
# Drop Article : 4, 윤미향 ‘횡령·배임’ 여부 초점…거래내역 공개 왜 못하나?
# input must have more than one sentence
# Drop Article : 0, [오늘의 키워드] 성추행 혐의 외교관에 소극 대응 비판…강경화의 선택은?
# input must have more than one sentence
# Drop Article : 0, [오늘 기업 오늘 사람] 홍콩상하이은행·삼양식품·현대제철·AK홀딩스
# input must have more than one sentence
# Drop Article : 1, [오늘 기업 오늘 사람] 홍콩상하이은행·삼양식품·현대제철·AK홀딩스
# input must have more than one sentence
# Drop Article : 2, [오늘 기업 오늘 사람] 홍콩상하이은행·삼양식품·현대제철·AK홀딩스
# input must have more than one sentence
# Drop Article : 4, [오늘 기업 오늘 사람] 홍콩상하이은행·삼양식품·현대제철·AK홀딩스
# input must have more than one sentence
# Drop Article : 1, 위·중증 환자 100명대 진입…정세균 “전공의 돌아와달라”
# input must have more than one sentence
# Drop Article : 2, 위·중증 환자 100명대 진입…정세균 “전공의 돌아와달라”
# input must have more than one sentence
# Drop Article : 4, 위·중증 환자 100명대 진입…정세균 “전공의 돌아와달라”
# input must have more than one sentence
# Drop Article : 5, 위·중증 환자 100명대 진입…정세균 “전공의 돌아와달라”
# input must have more than one sentence
# Drop Article : 5, 전공의, 내일 진료 복귀…의대생 구제 않으면 업무중단 시사
# input must have more than one sentence
# Drop Article : 1, [오늘 기업 오늘 사람] 남선알미늄·골드만삭스·코오롱생명과학
# input must have more than one sentence
# Drop Article : 2, [오늘 기업 오늘 사람] 남선알미늄·골드만삭스·코오롱생명과학
# input must have more than one sentence
# Drop Article : 1, [이슈분석] 정부, 부동산 거래 감시…부동산거래분석원 설치 공식화
# input must have more than one sentence
# Drop Article : 2, [이슈분석] 정부, 부동산 거래 감시…부동산거래분석원 설치 공식화
# input must have more than one sentence
# Drop Article : 3, [이슈분석] 정부, 부동산 거래 감시…부동산거래분석원 설치 공식화
# input must have more than one sentence
# Drop Article : 4, [이슈분석] 정부, 부동산 거래 감시…부동산거래분석원 설치 공식화
# input must have more than one sentence
# Drop Article : 1, [이슈분석] 트럼프, 中때리기로 관심 끌기?…지지율 하락에 돌발행동
# input must have more than one sentence
# Drop Article : 2, [이슈분석] 트럼프, 中때리기로 관심 끌기?…지지율 하락에 돌발행동
# input must have more than one sentence
# Drop Article : 3, [이슈분석] 트럼프, 中때리기로 관심 끌기?…지지율 하락에 돌발행동
# input must have more than one sentence
# Drop Article : 4, [이슈분석] 트럼프, 中때리기로 관심 끌기?…지지율 하락에 돌발행동
# input must have more than one sentence
# Drop Article : 5, [이슈분석] 트럼프, 中때리기로 관심 끌기?…지지율 하락에 돌발행동
# input must have more than one sentence
# Drop Article : 3, [집중진단] 전세기 탑승 우한교민 “답답해도 받아들여야”
# SBS funE /data/ksb/TestDir/articles/Preprocessed-Data/SBS funE.csv
# SBS /data/ksb/TestDir/articles/Preprocessed-Data/SBS.csv
# input must have more than one sentence
# Drop Article : 0, [인터뷰] 우상호 "위기의 서울시, 가장 준비된 후보라 자신"
# input must have more than one sentence
# Drop Article : 0, [인터뷰] 김태년 "추미애-강경화, 與 대응 차이? 과한 해석"
# input must have more than one sentence
# Drop Article : 0, 끝나지 않은 장마, 곳곳 물바다…주말 또 폭우 쏟아진다
# input must have more than one sentence
# Drop Article : 0, CCTV도 확보했지만…서울역 폭행범, 왜 영장 기각됐나
# input must have more than one sentence
# Drop Article : 0, 정인이 학대 신고 3차례나 묵살…왜 살인죄 아닌가
# input must have more than one sentence
# Drop Article : 0, "방임도 학대"…"내복 차림" 아이 CCTV가 말하는 것
# input must have more than one sentence
# Drop Article : 0, 정치권도 "정인아 미안해"…"대책 마련" 한목소리
# input must have more than one sentence
# Drop Article : 0, [인터뷰] "김정은 사망 99% 확신" 지성호 주장 이유는?
# input must have more than one sentence
# Drop Article : 3, [인터뷰] "김정은 사망 99% 확신" 지성호 주장 이유는?
# input must have more than one sentence
# Drop Article : 0, [인터뷰] "유승민에 심쿵" 김웅 마음 사로잡은 말은…
# input must have more than one sentence
# Drop Article : 0, "우린 또 당하는구나"…매 맞는 구급대원의 "무력감"
# TV조선 /data/ksb/TestDir/articles/Preprocessed-Data/TV조선.csv
# input must have more than one sentence
# Drop Article : 1, 한국당, 첫 상설특검 수사요구안 제출…"추미애 수사해야"
# input must have more than one sentence
# Drop Article : 0, 박상학 "어젯밤 파주서 대북전단 50만장 기습 살포"
# input must have more than one sentence
# Drop Article : 1, 문고리에 침 뱉고 격리 호텔엔 의료진 無…"中 감염 확산 당연"
# input must have more than one sentence
# Drop Article : 1, 의료진 "코로나19" 감염 속출…은평성모 확진 5명으로 늘어
# ZDNet Korea /data/ksb/TestDir/articles/Preprocessed-Data/ZDNet Korea.csv
# 기자협회보 /data/ksb/TestDir/articles/Preprocessed-Data/기자협회보.csv
