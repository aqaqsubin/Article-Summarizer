# %% [markdown]
# ### **Word2Vec**
#
# 원 핫 인코딩을 사용하면서도 단어 간 유사도를 반영할 수 있도록 단어의 의미를 벡터화하는 방법이다.
#
# *비슷한 위치에서 등장하는 단어들은 비슷한 의미를 가진다*는 분포 가설을 따르는 분산 표현 방법을 사용한다.
#
# 예) '강아지'는 주로 '귀엽다','예쁘다' 등의 단어와 함께 등장하는데, 이러한 내용을 가지는 텍스트를 벡터화하면 이 단어들은 의미적으로 가까운 단어가 된다.
#
# <br>
# Word2Vec에는 다음 두 가지 방식이 있다.
#
# - CBOW(Continous Bag of Words)
# - Skip-Gram

# %% [markdown]
# #### **CBOW(Continous Bag of Words)**
#
# 주변에 있는 단어들을 통해 중간에 있는 단어를 예측하는 방법이다.
# 윈도우를 두고, 윈도우 내의 주변 단어의 벡터로 중심 단어의 벡터를 예측한다.
# Skip-Gram에 비해 몇 배 빠른 훈련이 가능하며, 빈번한 단어를 예측하는 데 더 나은 정확도를 가진다.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import re
from pathlib import Path

# %%
BASE_DIR = "/data/ksb/TestDir"
DATA_BASE_DIR = os.path.join(BASE_DIR, "sample_articles")

ORIGIN_PATH = os.path.join(DATA_BASE_DIR,"Origin-Data")
PREPROCESSED_PATH = os.path.join(DATA_BASE_DIR,"Preprocessed-Data")
PRETTY_PATH = os.path.join(DATA_BASE_DIR,"Pretty-Data")
SWORDS_PATH = os.path.join(DATA_BASE_DIR, "StopWordList.txt")
MODEL_PATH = os.path.join(os.path.join(Path(os.getcwd()).parent, "Word-Embedding-Model"))

# %%
def mkdir_p(path):
    import errno
    try:
        os.makedirs(path)
    except OSError as exc:
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

def del_folder(path):
    from shutil import rmtree
    try:
        rmtree(path)
    except Exception as e:
        print(e)
        pass

# %%
class RawTextReader:
    def __init__(self, filepath):
        self.filepath = filepath
        self.rgxSplitter = re.compile("/n")

    def __iter__(self):
        for line in open(self.filepath, encoding='utf-8'):
            ch = self.rgxSplitter.split(line)
            for s in ch:
                yield s

# %% [markdown]
# 경향신문 언론사 첫번째 기사를 예시로 전처리된 텍스트를 토큰화 한다.

# %%
media_list = os.listdir(ORIGIN_PATH)

media = media_list[2]
media_path = os.path.join(PREPROCESSED_PATH, media)
article_list= os.listdir(media_path)

article = article_list[0]
reader = RawTextReader(os.path.join(media_path, article))
    
content = list(filter(None, reader))
content
# Out:
# ['진행',
#  '강진원 앵커 박상연 앵커 출연',
#  '김광삼 변호사 재원 부산 가톨릭대 특 임 교수 아래 텍스트 실제 방송 내용 차이 있 있 내용 방송 확인 바라',
#  '대법원 선고 결과 이재명 경기 지사 관련 대법원 선고 결과 관련 전문가 내용 짚',
#  '변호사 주문 있 제가 읽',
#  '다수 의견 다음 판결',
#  '원심 판결 유무 죄 부분 포함 유죄 부분 파기 부분 사건 수원 고등법원 환송',
#  '허위 사실 공표 관련 내용 무죄 취지 파기 환송 이렇 보',
#  '말씀',
#  '무죄 취지 파기 환송 하 이건 서울고등법원 재판 하 되',
#  '대법원 무죄 취지 서울 고등 취지 귀속 되 없',
#  '결과 이재명 지사 원고 무죄 판결 받 되 이렇 보 있',
#  '대하 만약 검찰 상고 하 되 대법원 재판 받 되 그렇 결과 영향 미치 선고 나오 이렇 보 있',
#  '실익 없 검찰 입장',
#  '맞',
#  '사실 일각 사건 전원 합의체 넘어가 자체 지사 긍정 있 시각 있',
#  '맞',
#  '전원 합의체 넘어가 이례 중계 대법원 결정',
#  '그렇 많 전문가 심의 결과 반대 결과 차원 대법원 부분 홍보 하 생각 들 오늘 전원 합의체 다수 의견 자체 허위 사실 공표 죄 새롭 판례 확립',
#  '측면 부분 적극 알리 하 부분 반영 차원 이재명 지사 대하 무죄 선고 자체 강도 높 예측 순간',
#  '이재명 경기 지사 같 경우 여권 차기 대선 주자 꼽히 인물 오늘 선고 결과 대하 관심 정치 뜨겁',
#  '정치 반응 나오 같 국회 연결 알아보',
#  '오늘 판결 대하 정치 반응 정리',
#  '더불어민주당 한숨 돌리 분위기',
#  '지사 여권 대권 가도 이낙연 의원 뒤쫓 경쟁자',
#  '지사 원심 확정 판결 받 내후년 대통령 선거 출마 없 되 민주당 대선 후보 잃 되 위기',
#  '대선 주자 안희정 충남 지사 박원순 서울 시장 낙 마한 상황 차기 대권 구도 적신호 켜 우려 나오',
#  '무죄 취지 파기 환송 결정 나 걱정 씻 되',
#  '지사 정치 위기 벗어나 남은 동안 도정 안정 운영 동력 얻 되',
#  '이낙연 의원 뒤쫓 차기 대권 지지 율도 상승세 이후 대선 행보 청신호 켜 분석',
#  '서울 부산 시장 경기도지사 빈자리 되 초유 상황 피하 있 되',
#  '대하 미래 통합 당 반응 어떻',
#  '통합 대법원 판결 물음표 그리',
#  '사법부 판결 존중 게 법 법관 양심 근거 객관 판단 의문 겁 니다',
#  '경기도민 형 정신병원 강제 입원 허위 사실 유포 의혹 혐의 얼룩지 지사 권한 행사 지켜보 하 법리 무죄 선고 정치 유죄 밝히',
#  '부산 서울 경기도 수장 공백 사태 오 다행 말',
#  '지사 자리 잃 되 통합 내년 4월 보궐 선거 정부 심판 넘 정권 교체 몰아가 전망 나오',
#  '경기 사직 빠지 내년 보궐 선거 서울 부산 시장 두 사실 대선 전초전 치르',
#  '민주당 당장 후보 내 고민 빠지 모습',
#  '반면 통합 서울시 장과 부산 시장 보궐 선거 낙관 측면 있 말 강하 자신감 드러내 있',
#  '지금 국회 전하 드리',
#  '정치 반응 알아보',
#  '앞으로 이재명 지사 정치 인생 대하 짚 없 정치 이번 선고 결과 예의 주시 한 이유 있 겁 니다',
#  '여권 대권 주자 이기',
#  '그렇',
#  '이재명 지사 여권 잠재 주자 달리 있',
#  '지지 급 상승세 있 상황',
#  '여기 박원순 시장 예상 극단 선택 여권 잠재 주자 사라지 상황 만약 이재명 지사 낙 마 경우 내년 민주당 대권 경선 자체 어떻 보 이낙연 주자 혼자 홀로 경선 되 높',
#  '그렇 하 흥행 찬물 끼얹 없 상황',
#  '리포트 하 민주당 입장 집권 여당 입장 안도 한숨 내쉬 없',
#  '부산 서울까지',
#  '여기 경기 지사 낙 마 경우 집권 여당 책임 있 내년 보궐 선거 전국 크 광역 단체 선거 이루어지 상황 상당 부담 가지 없 부분 모면 있',
#  '이번 결정 반기 사람 이재명 지 사',
#  '이재명 지사 사실 정치 입지전 인물 알리 있 이미지 추가 같',
#  '오뚝이 이미지',
#  '사실 이재명 지사 오 과정 정치 고난 겪',
#  '지나 경기 지사 선거 관련 자신 주어지 상당 걸림돌 크 여배우 스캔들',
#  '여배우 스캔들 혐의 되 경찰 단계 끝나 남은 형 강제 입원 관련 논란 부분 대법원 완전 크 리어 정리 본인 입장 정치 추세 풀리',
#  '그렇 하 급상승 있 지지 변화 여권 구도 차기 대권 구도 자체 진행 있',
#  '그렇 측면 보 이재명 지사 입장 이제 크 날개 펴 웅비 순간 있 전망 나오 있 상황 같',
#  '정치 숨 가쁘 판단 내리 같 오늘 선고 관련 이재명 경기도지사 변호인 입장 들어오',
#  '들',
#  '지금 이재명 경기도지사 변호인 오늘 대법원 선고 결과 대하 입장 들',
#  '지금 선고 취지 대하 전문가 들 하',
#  '변호사 오늘 무죄 취지 사건 파기 환송 허위 사실 공표 부분 대하',
#  '중계로 들 핵심 같',
#  '후보자 토론회 과정 즉흥 진행 한계 있 토론 자유 보장 되 취지 같 구체 내용 설명',
#  '전체 취지',
#  '후보자 토론회 방송 후보자 토론회 시간 제약 있',
#  '답 시간 그렇 숨 가쁘 돌아가',
#  '제약 있 다음 사실 방송 토론 하 보 준비 원고 하 없',
#  '즉흥 면 있 하 보 표현 경우 있',
#  '자신 처하 입장 어떻 보 변호 상황 되 있',
#  '대법원 같',
#  '표현 표현 하 자체 법 처벌 자체 방송 토론 선거 운동 제약 되',
#  '궁극 말하자면 선거 운동 자체 본질 침해',
#  '대법원 판결 이유 같',
#  '결론 이야기 의도 적극 왜곡 의도 하 모르 해명 차원 하 하 이건 허위 사실 공표 보 없',
#  '공표 자체 적극 의미 해석 겁 니다',
#  '일부 있 사실 다르 하 해명 과정 대하 소극 대답 하 하 공표 라고 보 없 이렇 보 같',
#  '이전 대법원 판결 있 이번 판결 자체 전원 합의체 하 의미 있',
#  '사실 허위 사실 공표 관련 허위 사실 공표 이 추상 개념',
#  '오늘 전원 합의체 판결 허위 사실 관련 한계 방송 토론회 한계 공표 의미 자체 적극 띄 하 의미 선고 하 향후 있 허위 사실 공표 관련 부분 상당 부분 정리 되 보',
#  '자비 고소 고발 일삼 이재명 지사 관하 판결 심 무죄 심 유죄 나오 말',
#  '어떻 보 법 전문 하 판사 자체 부분 대하 시각 가지',
#  '오늘 전원 합의체 판결 부분 해석 이렇 판단 보 있',
#  '이후 절차 대하 살펴보',
#  '말씀 하 오늘 대법원 원심 무죄 취지 어떻 보 파기 사건 수원 고등법원 돌려보내',
#  '원고 법 파기 환송 심 진행 예정 대법원 선고 결과 귀속 무죄 취지 판결 나오 높',
#  '그렇',
#  '파기 환송 심 재판 걸리 예',
#  '사건 시작',
#  '심 통하 엄청나 공방 하 대법원 판결 증거 사실관계 정리 되',
#  '부분 대하 사실 검찰 이의 제기 하 새롭 증거 내 있 없',
#  '대법원 판단 자체 법률 해석 관하 판단',
#  '법률 해석 검찰 다르 하 하 어떻 보 뒤집 없',
#  '파기 환송 심 이재용 부회장 최 서원 판결 박근혜 대통령 대하 파기 환송 다르 파기 환송 심 원고 이루어지 되 절차 신속 진행 크',
#  '법률 해석 관하 정리 하 되',
#  '검찰 상고 대상 되 사건 비하 시간 걸리',
#  '오늘 전원 합의체 판결 이재명 지사 자유 보 있',
#  '향후 대법원 상고 하 이재명 지사 정치 활동 하 제약 없 이렇 보 되',
#  '최종 결론 나오 때 시간 걸리 말씀 하',
#  '정치 파장 대하 얘기 나누',
#  '교수 말씀 최근 지사 지지도 오르 모습 이낙연 의원 대하 말씀 하',
#  '이낙연 의원 이재명 지사',
#  '지지도 게 어떻 예상 되',
#  '이재명 지사 급 상승세 지지 보이 이유 이번 코로나 사태 관련 상당 대로 정치 순발력 통하 국민 다가가 행정가 모습 보이 겁 니다',
#  '예 들 코로나 대하 신천지 대하 강제 명령 부분',
#  '코로나 사태 경제 어려움 재난 대하 기본소득 주장 사실 재난 지원금 국민 지급 어떻 보 물꼬 트 측면',
#  '지금 기본소득 대하 이야기 이야기 국정 현안 대하 아 젠 다 주도 모습 보이 있 겁 니다',
#  '상황 사실 어떻 보 정치 족쇄 지나 경기 지사 선거 때 법률 문제 해소 되 이제 걸림돌 사라지',
#  '그렇 하 본인 정치 공간 넓 측면',
#  '상승세 있 지지 바탕 하 공격 행보 하 높',
#  '대법원 판결 나오 전 이야기 하',
#  '자신 향후 정치 역점 관련 대선 도전 대하 조심 태도 보이',
#  '목이 날아가 상황 그렇 대선 경기도지사 재선 방점 두 모습 보이 하 이제 상황 달라지',
#  '그렇 하 본인 입장 공격 적극 행보 하',
#  '사실 이번 코로나 사태 직후 본인 공격 모습 보이 있 예 들 문계 인사 영입',
#  '이번 대북 전단 사건 관련 통일부 있 때 부분 적극 하 예 들 여권 지지 강하 결집 받 모습 보이',
#  '그렇 하 앞 전도 유망 가 있',
#  '그렇 겁 니다',
#  '사실 이재명 지사 법률 크 리어 문 지지 정치 앙금 남 있 겁 니다',
#  '과거 경기 지사 사건 때 논란 많',
#  '그때 문 세력 이재명 지사 정치 갈등 얼마 본인 스스로 털 화해 나가 있',
#  '이번 전당 대회 8월 있',
#  '8월 달 전당 대회 이낙연 의원 당 권 주자 급부상 있 이낙연 지사 내년 3월 한정 당 장악 예 들 당내 조직 확보 경우 내년 경선 자체 당내 조직 열세 이재명 지사 감당 부담 있 전망 있 모르',
#  '본인 생각 정책 행보 적극 하 높 보',
#  '통합 당의 같 어떻',
#  '그렇 통합 입장 사실 이번 판결 대하 유감 뜻 표하 있 이재명 지사 이번 대권 주자 살아나 측면 위협 느끼 하 생각',
#  '제가 말씀 드리 이재명 지사 낙 마하 경우 되 하 여당 경선 자체 흥행 요소 사라지 높',
#  '그렇 하 이낙연 의원 단독 만약 추대 경우 본선 쉽 올라가 있 보 있 당내 경선 되 본선 후보 상당 경쟁력 가지 있',
#  '측면 보 하 미래 통합 당 입장 차기 대선 내세우 있 후보 선임 없 상황',
#  '당장 알 미래 통합 차기 대선 주자 관련 풀 한계 있',
#  '측면 새롭 인물 새롭 시대정신 가지 사람 발굴 되 정치 과제 무겁 하 생각',
#  '이번 사건 다수 의견 따르 전원 합의체 판단 원심 유죄 선고 부분 무죄 취지 파기 환송',
#  '전 열리 대법원 선고 핵심 내용 들',
#  '대법원장 오늘 선고 취지 대하 들',
#  '변호사 말씀 드리 있 오늘 대법원 선고 다수 의견 소수의견 갈리',
#  '원래 이 대법원 법관 소부 회부 되 소부 만장일치 의견 일치 보 되 의견 일치 되 전원 합의체 넘어가',
#  '법관 사이에서 정도 이견 차 보 어떻',
#  '소부 법관 구성 있',
#  '만장일치 되 전원 합의체 넘기 회부 하',
#  '만장일치 되 되 대하 사실',
#  '만장일치 되 때 전원 합의체 회부 있',
#  '사회 이목 끌 사건 대하 사실 법관 하 자체 그렇 결정 문제 있 있 전원 합의체 회부 판결 의도 있 있 소부 만장일치 되 있',
#  '만장일치 되 하 전원 합의체 회부 있 개인 의견 보 때 만장일치 나오 같',
#  '주심 판사 노 정희 주심 이전 춘천 사건',
#  '그때 판결 이유 같 똑같 이유 무죄 취지 파기 환송 경우 있',
#  '개인 보 때 아마 주 심 판사 입장 파기 환송 의지 가지 있 그렇 보 그렇 하 결과 오늘 보 소수 의견 다음 다수',
#  '법관 인원수 찬성 반대 차이 그렇 크',
#  '만약 이중 의견 하 판결 뒤바뀌 있 경우',
#  '결과 이상 다수 의견 되 이재명 지사 살아나 이렇 보 있',
#  '말씀 이렇 법관 사이에서 사회 사안 바라보 시각 있 사안 대법원 이례',
#  '이렇 선고 결과 중계 게',
#  '박근혜 대통령 국정 농 단 사건 이후 이',
#  '그렇',
#  '자치 단체장 처음 이재명 지사',
#  '사실 선고 대하 공개 대하 규정 나오 오래되 대법원 자체',
#  '이재명 지사 대하 선고 사실 유죄 부분 대하 공직 선거법 위반 허위 사실 공표 대하 사실 법리 그렇 어렵',
#  '대법원 선고 되 공개',
#  '사회 이목 집중 사건 보 있 이 선고 같 전원 합의체 회부 하 공개 하 있',
#  '허위 사실 공표 죄 관하 대법원 법리 국민 알리 하 측면 있',
#  '그렇 보',
#  '오늘 이재명 지사 대법원 나오 대법원 판결 같 경우 나오 되',
#  '그렇 일반 형사 사건 심 심 선고 날 나오 출석 하 하',
#  '만약 출석 하 되 영장 발부 하 되',
#  '피고인 없 상태 선고 하',
#  '대부분 실형 선고 하',
#  '대법원 같 경우 실질 심리 자체 피고인 법정 출석 하 심리 서면 심리',
#  '법률 심이기 선고 때 피고인 출석 되',
#  '이재명 지사 사실 쟁점 되 허위 사실 공표 죄 대하 위헌법률심판 제청 신청서 제출 대법 공개 변론 신청 하',
#  '그렇 되 이렇 적극 방어 보',
#  '본인 입장 엄청나',
#  '경기 지사 만약 대법원 유죄 확정 향후 본인 정치 재기 없 상황 5년 피선거권 박탈 선거 자금 정도 보존',
#  '사실 반환 하 입장 보 본인 입장 절대절명 사력 재판 임하 없 상황 보',
#  '하 있 방법 꺼내',
#  '통하 생각 하',
#  '법리 측면 심 유죄 나오 변호사 이재명 지사 변호사 출신',
#  '많 숙고 공부 하',
#  '오늘 대법원 판결 끌어내 이렇 보 있',
#  '마지막 교수 내년 보선 서울시 부산시 곳 치르',
#  '그렇',
#  '이번 경기도지사 대하 재판 자체 원심 대하 파기 환송 가 내년 경기도지사 선거 없 보 되 같',
#  '그럼에도 불구하고 내년 선거 이유 우리나라 도시 단체장 뽑 선거',
#  '민주당 소속 광역 단체장 자신 귀책사유 인하 선거 치르 상황 민주당 입장 정치 수세 몰리 없',
#  '그렇 하 귀책사유 있 하 후보',
#  '그렇 없 이야기 당 나오 겁 니다',
#  '당헌 그렇 규정 있 내년 보궐 선거 그 후 있 대통령 선거 크 영향 없 상황',
#  '측면 보 경기도지사 살아나 경기도지사 빠지 내년 4월 보궐 선거 상당 정치 의미 계속 이어지 없 상황 같',
#  '알',
#  '이재명 경기 지사 오늘 선고 결과 회견 하 소식 들어오',
#  '기자회견 장면 이어지 뉴스 전해 드리 하',
#  '지금 김광삼 변호사 재원 부산 가톨릭대 특 임 교수 이야기 나누',
#  '오늘 말씀 고맙습니다']

# %%
tokenList = [sent.split() for sent in content]
tokenList
# Out:
# [['진행'],
#  ['강진원', '앵커', '박상연', '앵커', '출연'],
#  ['김광삼',
#   '변호사',
#   '재원',
#   '부산',
#   '가톨릭대',
#   '특',
#   '임',
#   '교수',
#   '아래',
#   '텍스트',
#   '실제',
#   '방송',
#   '내용',
#   '차이',
#   '있',
#   '있',
#   '내용',
#   '방송',
#   '확인',
#   '바라'],
#  ['대법원',
#   '선고',
#   '결과',
#   '이재명',
#   '경기',
#   '지사',
#   '관련',
#   '대법원',
#   '선고',
#   '결과',
#   '관련',
#   '전문가',
#   '내용',
#   '짚'],
#  ['변호사', '주문', '있', '제가', '읽'],
#  ['다수', '의견', '다음', '판결'],
#  ['원심',
#   '판결',
#   '유무',
#   '죄',
#   '부분',
#   '포함',
#   '유죄',
#   '부분',
#   '파기',
#   '부분',
#   '사건',
#   '수원',
#   '고등법원',
#   '환송'],
#  ['허위', '사실', '공표', '관련', '내용', '무죄', '취지', '파기', '환송', '이렇', '보'],
#  ['말씀'],
#  ['무죄', '취지', '파기', '환송', '하', '이건', '서울고등법원', '재판', '하', '되'],
#  ['대법원', '무죄', '취지', '서울', '고등', '취지', '귀속', '되', '없'],
#  ['결과', '이재명', '지사', '원고', '무죄', '판결', '받', '되', '이렇', '보', '있'],
#  ['대하',
#   '만약',
#   '검찰',
#   '상고',
#   '하',
#   '되',
#   '대법원',
#   '재판',
#   '받',
#   '되',
#   '그렇',
#   '결과',
#   '영향',
#   '미치',
#   '선고',
#   '나오',
#   '이렇',
#   '보',
#   '있'],
#  ['실익', '없', '검찰', '입장'],
#  ['맞'],
#  ['사실', '일각', '사건', '전원', '합의체', '넘어가', '자체', '지사', '긍정', '있', '시각', '있'],
#  ['맞'],
#  ['전원', '합의체', '넘어가', '이례', '중계', '대법원', '결정'],
#  ['그렇',
#   '많',
#   '전문가',
#   '심의',
#   '결과',
#   '반대',
#   '결과',
#   '차원',
#   '대법원',
#   '부분',
#   '홍보',
#   '하',
#   '생각',
#   '들',
#   '오늘',
#   '전원',
#   '합의체',
#   '다수',
#   '의견',
#   '자체',
#   '허위',
#   '사실',
#   '공표',
#   '죄',
#   '새롭',
#   '판례',
#   '확립'],
#  ['측면',
#   '부분',
#   '적극',
#   '알리',
#   '하',
#   '부분',
#   '반영',
#   '차원',
#   '이재명',
#   '지사',
#   '대하',
#   '무죄',
#   '선고',
#   '자체',
#   '강도',
#   '높',
#   '예측',
#   '순간'],
#  ['이재명',
#   '경기',
#   '지사',
#   '같',
#   '경우',
#   '여권',
#   '차기',
#   '대선',
#   '주자',
#   '꼽히',
#   '인물',
#   '오늘',
#   '선고',
#   '결과',
#   '대하',
#   '관심',
#   '정치',
#   '뜨겁'],
#  ['정치', '반응', '나오', '같', '국회', '연결', '알아보'],
#  ['오늘', '판결', '대하', '정치', '반응', '정리'],
#  ['더불어민주당', '한숨', '돌리', '분위기'],
#  ['지사', '여권', '대권', '가도', '이낙연', '의원', '뒤쫓', '경쟁자'],
#  ['지사',
#   '원심',
#   '확정',
#   '판결',
#   '받',
#   '내후년',
#   '대통령',
#   '선거',
#   '출마',
#   '없',
#   '되',
#   '민주당',
#   '대선',
#   '후보',
#   '잃',
#   '되',
#   '위기'],
#  ['대선',
#   '주자',
#   '안희정',
#   '충남',
#   '지사',
#   '박원순',
#   '서울',
#   '시장',
#   '낙',
#   '마한',
#   '상황',
#   '차기',
#   '대권',
#   '구도',
#   '적신호',
#   '켜',
#   '우려',
#   '나오'],
#  ['무죄', '취지', '파기', '환송', '결정', '나', '걱정', '씻', '되'],
#  ['지사', '정치', '위기', '벗어나', '남은', '동안', '도정', '안정', '운영', '동력', '얻', '되'],
#  ['이낙연',
#   '의원',
#   '뒤쫓',
#   '차기',
#   '대권',
#   '지지',
#   '율도',
#   '상승세',
#   '이후',
#   '대선',
#   '행보',
#   '청신호',
#   '켜',
#   '분석'],
#  ['서울', '부산', '시장', '경기도지사', '빈자리', '되', '초유', '상황', '피하', '있', '되'],
#  ['대하', '미래', '통합', '당', '반응', '어떻'],
#  ['통합', '대법원', '판결', '물음표', '그리'],
#  ['사법부', '판결', '존중', '게', '법', '법관', '양심', '근거', '객관', '판단', '의문', '겁', '니다'],
#  ['경기도민',
#   '형',
#   '정신병원',
#   '강제',
#   '입원',
#   '허위',
#   '사실',
#   '유포',
#   '의혹',
#   '혐의',
#   '얼룩지',
#   '지사',
#   '권한',
#   '행사',
#   '지켜보',
#   '하',
#   '법리',
#   '무죄',
#   '선고',
#   '정치',
#   '유죄',
#   '밝히'],
#  ['부산', '서울', '경기도', '수장', '공백', '사태', '오', '다행', '말'],
#  ['지사',
#   '자리',
#   '잃',
#   '되',
#   '통합',
#   '내년',
#   '4월',
#   '보궐',
#   '선거',
#   '정부',
#   '심판',
#   '넘',
#   '정권',
#   '교체',
#   '몰아가',
#   '전망',
#   '나오'],
#  ['경기',
#   '사직',
#   '빠지',
#   '내년',
#   '보궐',
#   '선거',
#   '서울',
#   '부산',
#   '시장',
#   '두',
#   '사실',
#   '대선',
#   '전초전',
#   '치르'],
#  ['민주당', '당장', '후보', '내', '고민', '빠지', '모습'],
#  ['반면',
#   '통합',
#   '서울시',
#   '장과',
#   '부산',
#   '시장',
#   '보궐',
#   '선거',
#   '낙관',
#   '측면',
#   '있',
#   '말',
#   '강하',
#   '자신감',
#   '드러내',
#   '있'],
#  ['지금', '국회', '전하', '드리'],
#  ['정치', '반응', '알아보'],
#  ['앞으로',
#   '이재명',
#   '지사',
#   '정치',
#   '인생',
#   '대하',
#   '짚',
#   '없',
#   '정치',
#   '이번',
#   '선고',
#   '결과',
#   '예의',
#   '주시',
#   '한',
#   '이유',
#   '있',
#   '겁',
#   '니다'],
#  ['여권', '대권', '주자', '이기'],
#  ['그렇'],
#  ['이재명', '지사', '여권', '잠재', '주자', '달리', '있'],
#  ['지지', '급', '상승세', '있', '상황'],
#  ['여기',
#   '박원순',
#   '시장',
#   '예상',
#   '극단',
#   '선택',
#   '여권',
#   '잠재',
#   '주자',
#   '사라지',
#   '상황',
#   '만약',
#   '이재명',
#   '지사',
#   '낙',
#   '마',
#   '경우',
#   '내년',
#   '민주당',
#   '대권',
#   '경선',
#   '자체',
#   '어떻',
#   '보',
#   '이낙연',
#   '주자',
#   '혼자',
#   '홀로',
#   '경선',
#   '되',
#   '높'],
#  ['그렇', '하', '흥행', '찬물', '끼얹', '없', '상황'],
#  ['리포트', '하', '민주당', '입장', '집권', '여당', '입장', '안도', '한숨', '내쉬', '없'],
#  ['부산', '서울까지'],
#  ['여기',
#   '경기',
#   '지사',
#   '낙',
#   '마',
#   '경우',
#   '집권',
#   '여당',
#   '책임',
#   '있',
#   '내년',
#   '보궐',
#   '선거',
#   '전국',
#   '크',
#   '광역',
#   '단체',
#   '선거',
#   '이루어지',
#   '상황',
#   '상당',
#   '부담',
#   '가지',
#   '없',
#   '부분',
#   '모면',
#   '있'],
#  ['이번', '결정', '반기', '사람', '이재명', '지', '사'],
#  ['이재명', '지사', '사실', '정치', '입지전', '인물', '알리', '있', '이미지', '추가', '같'],
#  ['오뚝이', '이미지'],
#  ['사실', '이재명', '지사', '오', '과정', '정치', '고난', '겪'],
#  ['지나', '경기', '지사', '선거', '관련', '자신', '주어지', '상당', '걸림돌', '크', '여배우', '스캔들'],
#  ['여배우',
#   '스캔들',
#   '혐의',
#   '되',
#   '경찰',
#   '단계',
#   '끝나',
#   '남은',
#   '형',
#   '강제',
#   '입원',
#   '관련',
#   '논란',
#   '부분',
#   '대법원',
#   '완전',
#   '크',
#   '리어',
#   '정리',
#   '본인',
#   '입장',
#   '정치',
#   '추세',
#   '풀리'],
#  ['그렇',
#   '하',
#   '급상승',
#   '있',
#   '지지',
#   '변화',
#   '여권',
#   '구도',
#   '차기',
#   '대권',
#   '구도',
#   '자체',
#   '진행',
#   '있'],
#  ['그렇',
#   '측면',
#   '보',
#   '이재명',
#   '지사',
#   '입장',
#   '이제',
#   '크',
#   '날개',
#   '펴',
#   '웅비',
#   '순간',
#   '있',
#   '전망',
#   '나오',
#   '있',
#   '상황',
#   '같'],
#  ['정치',
#   '숨',
#   '가쁘',
#   '판단',
#   '내리',
#   '같',
#   '오늘',
#   '선고',
#   '관련',
#   '이재명',
#   '경기도지사',
#   '변호인',
#   '입장',
#   '들어오'],
#  ['들'],
#  ['지금', '이재명', '경기도지사', '변호인', '오늘', '대법원', '선고', '결과', '대하', '입장', '들'],
#  ['지금', '선고', '취지', '대하', '전문가', '들', '하'],
#  ['변호사', '오늘', '무죄', '취지', '사건', '파기', '환송', '허위', '사실', '공표', '부분', '대하'],
#  ['중계로', '들', '핵심', '같'],
#  ['후보자',
#   '토론회',
#   '과정',
#   '즉흥',
#   '진행',
#   '한계',
#   '있',
#   '토론',
#   '자유',
#   '보장',
#   '되',
#   '취지',
#   '같',
#   '구체',
#   '내용',
#   '설명'],
#  ['전체', '취지'],
#  ['후보자', '토론회', '방송', '후보자', '토론회', '시간', '제약', '있'],
#  ['답', '시간', '그렇', '숨', '가쁘', '돌아가'],
#  ['제약', '있', '다음', '사실', '방송', '토론', '하', '보', '준비', '원고', '하', '없'],
#  ['즉흥', '면', '있', '하', '보', '표현', '경우', '있'],
#  ['자신', '처하', '입장', '어떻', '보', '변호', '상황', '되', '있'],
#  ['대법원', '같'],
#  ['표현', '표현', '하', '자체', '법', '처벌', '자체', '방송', '토론', '선거', '운동', '제약', '되'],
#  ['궁극', '말하자면', '선거', '운동', '자체', '본질', '침해'],
#  ['대법원', '판결', '이유', '같'],
#  ['결론',
#   '이야기',
#   '의도',
#   '적극',
#   '왜곡',
#   '의도',
#   '하',
#   '모르',
#   '해명',
#   '차원',
#   '하',
#   '하',
#   '이건',
#   '허위',
#   '사실',
#   '공표',
#   '보',
#   '없'],
#  ['공표', '자체', '적극', '의미', '해석', '겁', '니다'],
#  ['일부',
#   '있',
#   '사실',
#   '다르',
#   '하',
#   '해명',
#   '과정',
#   '대하',
#   '소극',
#   '대답',
#   '하',
#   '하',
#   '공표',
#   '라고',
#   '보',
#   '없',
#   '이렇',
#   '보',
#   '같'],
#  ['이전', '대법원', '판결', '있', '이번', '판결', '자체', '전원', '합의체', '하', '의미', '있'],
#  ['사실', '허위', '사실', '공표', '관련', '허위', '사실', '공표', '이', '추상', '개념'],
#  ['오늘',
#   '전원',
#   '합의체',
#   '판결',
#   '허위',
#   '사실',
#   '관련',
#   '한계',
#   '방송',
#   '토론회',
#   '한계',
#   '공표',
#   '의미',
#   '자체',
#   '적극',
#   '띄',
#   '하',
#   '의미',
#   '선고',
#   '하',
#   '향후',
#   '있',
#   '허위',
#   '사실',
#   '공표',
#   '관련',
#   '부분',
#   '상당',
#   '부분',
#   '정리',
#   '되',
#   '보'],
#  ['자비',
#   '고소',
#   '고발',
#   '일삼',
#   '이재명',
#   '지사',
#   '관하',
#   '판결',
#   '심',
#   '무죄',
#   '심',
#   '유죄',
#   '나오',
#   '말'],
#  ['어떻', '보', '법', '전문', '하', '판사', '자체', '부분', '대하', '시각', '가지'],
#  ['오늘', '전원', '합의체', '판결', '부분', '해석', '이렇', '판단', '보', '있'],
#  ['이후', '절차', '대하', '살펴보'],
#  ['말씀',
#   '하',
#   '오늘',
#   '대법원',
#   '원심',
#   '무죄',
#   '취지',
#   '어떻',
#   '보',
#   '파기',
#   '사건',
#   '수원',
#   '고등법원',
#   '돌려보내'],
#  ['원고',
#   '법',
#   '파기',
#   '환송',
#   '심',
#   '진행',
#   '예정',
#   '대법원',
#   '선고',
#   '결과',
#   '귀속',
#   '무죄',
#   '취지',
#   '판결',
#   '나오',
#   '높'],
#  ['그렇'],
#  ['파기', '환송', '심', '재판', '걸리', '예'],
#  ['사건', '시작'],
#  ['심', '통하', '엄청나', '공방', '하', '대법원', '판결', '증거', '사실관계', '정리', '되'],
#  ['부분', '대하', '사실', '검찰', '이의', '제기', '하', '새롭', '증거', '내', '있', '없'],
#  ['대법원', '판단', '자체', '법률', '해석', '관하', '판단'],
#  ['법률', '해석', '검찰', '다르', '하', '하', '어떻', '보', '뒤집', '없'],
#  ['파기',
#   '환송',
#   '심',
#   '이재용',
#   '부회장',
#   '최',
#   '서원',
#   '판결',
#   '박근혜',
#   '대통령',
#   '대하',
#   '파기',
#   '환송',
#   '다르',
#   '파기',
#   '환송',
#   '심',
#   '원고',
#   '이루어지',
#   '되',
#   '절차',
#   '신속',
#   '진행',
#   '크'],
#  ['법률', '해석', '관하', '정리', '하', '되'],
#  ['검찰', '상고', '대상', '되', '사건', '비하', '시간', '걸리'],
#  ['오늘', '전원', '합의체', '판결', '이재명', '지사', '자유', '보', '있'],
#  ['향후',
#   '대법원',
#   '상고',
#   '하',
#   '이재명',
#   '지사',
#   '정치',
#   '활동',
#   '하',
#   '제약',
#   '없',
#   '이렇',
#   '보',
#   '되'],
#  ['최종', '결론', '나오', '때', '시간', '걸리', '말씀', '하'],
#  ['정치', '파장', '대하', '얘기', '나누'],
#  ['교수', '말씀', '최근', '지사', '지지도', '오르', '모습', '이낙연', '의원', '대하', '말씀', '하'],
#  ['이낙연', '의원', '이재명', '지사'],
#  ['지지도', '게', '어떻', '예상', '되'],
#  ['이재명',
#   '지사',
#   '급',
#   '상승세',
#   '지지',
#   '보이',
#   '이유',
#   '이번',
#   '코로나',
#   '사태',
#   '관련',
#   '상당',
#   '대로',
#   '정치',
#   '순발력',
#   '통하',
#   '국민',
#   '다가가',
#   '행정가',
#   '모습',
#   '보이',
#   '겁',
#   '니다'],
#  ['예', '들', '코로나', '대하', '신천지', '대하', '강제', '명령', '부분'],
#  ['코로나',
#   '사태',
#   '경제',
#   '어려움',
#   '재난',
#   '대하',
#   '기본소득',
#   '주장',
#   '사실',
#   '재난',
#   '지원금',
#   '국민',
#   '지급',
#   '어떻',
#   '보',
#   '물꼬',
#   '트',
#   '측면'],
#  ['지금',
#   '기본소득',
#   '대하',
#   '이야기',
#   '이야기',
#   '국정',
#   '현안',
#   '대하',
#   '아',
#   '젠',
#   '다',
#   '주도',
#   '모습',
#   '보이',
#   '있',
#   '겁',
#   '니다'],
#  ['상황',
#   '사실',
#   '어떻',
#   '보',
#   '정치',
#   '족쇄',
#   '지나',
#   '경기',
#   '지사',
#   '선거',
#   '때',
#   '법률',
#   '문제',
#   '해소',
#   '되',
#   '이제',
#   '걸림돌',
#   '사라지'],
#  ['그렇', '하', '본인', '정치', '공간', '넓', '측면'],
#  ['상승세', '있', '지지', '바탕', '하', '공격', '행보', '하', '높'],
#  ['대법원', '판결', '나오', '전', '이야기', '하'],
#  ['자신', '향후', '정치', '역점', '관련', '대선', '도전', '대하', '조심', '태도', '보이'],
#  ['목이',
#   '날아가',
#   '상황',
#   '그렇',
#   '대선',
#   '경기도지사',
#   '재선',
#   '방점',
#   '두',
#   '모습',
#   '보이',
#   '하',
#   '이제',
#   '상황',
#   '달라지'],
#  ['그렇', '하', '본인', '입장', '공격', '적극', '행보', '하'],
#  ['사실',
#   '이번',
#   '코로나',
#   '사태',
#   '직후',
#   '본인',
#   '공격',
#   '모습',
#   '보이',
#   '있',
#   '예',
#   '들',
#   '문계',
#   '인사',
#   '영입'],
#  ['이번',
#   '대북',
#   '전단',
#   '사건',
#   '관련',
#   '통일부',
#   '있',
#   '때',
#   '부분',
#   '적극',
#   '하',
#   '예',
#   '들',
#   '여권',
#   '지지',
#   '강하',
#   '결집',
#   '받',
#   '모습',
#   '보이'],
#  ['그렇', '하', '앞', '전도', '유망', '가', '있'],
#  ['그렇', '겁', '니다'],
#  ['사실',
#   '이재명',
#   '지사',
#   '법률',
#   '크',
#   '리어',
#   '문',
#   '지지',
#   '정치',
#   '앙금',
#   '남',
#   '있',
#   '겁',
#   '니다'],
#  ['과거', '경기', '지사', '사건', '때', '논란', '많'],
#  ['그때',
#   '문',
#   '세력',
#   '이재명',
#   '지사',
#   '정치',
#   '갈등',
#   '얼마',
#   '본인',
#   '스스로',
#   '털',
#   '화해',
#   '나가',
#   '있'],
#  ['이번', '전당', '대회', '8월', '있'],
#  ['8월',
#   '달',
#   '전당',
#   '대회',
#   '이낙연',
#   '의원',
#   '당',
#   '권',
#   '주자',
#   '급부상',
#   '있',
#   '이낙연',
#   '지사',
#   '내년',
#   '3월',
#   '한정',
#   '당',
#   '장악',
#   '예',
#   '들',
#   '당내',
#   '조직',
#   '확보',
#   '경우',
#   '내년',
#   '경선',
#   '자체',
#   '당내',
#   '조직',
#   '열세',
#   '이재명',
#   '지사',
#   '감당',
#   '부담',
#   '있',
#   '전망',
#   '있',
#   '모르'],
#  ['본인', '생각', '정책', '행보', '적극', '하', '높', '보'],
#  ['통합', '당의', '같', '어떻'],
#  ['그렇',
#   '통합',
#   '입장',
#   '사실',
#   '이번',
#   '판결',
#   '대하',
#   '유감',
#   '뜻',
#   '표하',
#   '있',
#   '이재명',
#   '지사',
#   '이번',
#   '대권',
#   '주자',
#   '살아나',
#   '측면',
#   '위협',
#   '느끼',
#   '하',
#   '생각'],
#  ['제가',
#   '말씀',
#   '드리',
#   '이재명',
#   '지사',
#   '낙',
#   '마하',
#   '경우',
#   '되',
#   '하',
#   '여당',
#   '경선',
#   '자체',
#   '흥행',
#   '요소',
#   '사라지',
#   '높'],
#  ['그렇',
#   '하',
#   '이낙연',
#   '의원',
#   '단독',
#   '만약',
#   '추대',
#   '경우',
#   '본선',
#   '쉽',
#   '올라가',
#   '있',
#   '보',
#   '있',
#   '당내',
#   '경선',
#   '되',
#   '본선',
#   '후보',
#   '상당',
#   '경쟁력',
#   '가지',
#   '있'],
#  ['측면',
#   '보',
#   '하',
#   '미래',
#   '통합',
#   '당',
#   '입장',
#   '차기',
#   '대선',
#   '내세우',
#   '있',
#   '후보',
#   '선임',
#   '없',
#   '상황'],
#  ['당장', '알', '미래', '통합', '차기', '대선', '주자', '관련', '풀', '한계', '있'],
#  ['측면',
#   '새롭',
#   '인물',
#   '새롭',
#   '시대정신',
#   '가지',
#   '사람',
#   '발굴',
#   '되',
#   '정치',
#   '과제',
#   '무겁',
#   '하',
#   '생각'],
#  ['이번',
#   '사건',
#   '다수',
#   '의견',
#   '따르',
#   '전원',
#   '합의체',
#   '판단',
#   '원심',
#   '유죄',
#   '선고',
#   '부분',
#   '무죄',
#   '취지',
#   '파기',
#   '환송'],
#  ['전', '열리', '대법원', '선고', '핵심', '내용', '들'],
#  ['대법원장', '오늘', '선고', '취지', '대하', '들'],
#  ['변호사', '말씀', '드리', '있', '오늘', '대법원', '선고', '다수', '의견', '소수의견', '갈리'],
#  ['원래',
#   '이',
#   '대법원',
#   '법관',
#   '소부',
#   '회부',
#   '되',
#   '소부',
#   '만장일치',
#   '의견',
#   '일치',
#   '보',
#   '되',
#   '의견',
#   '일치',
#   '되',
#   '전원',
#   '합의체',
#   '넘어가'],
#  ['법관', '사이에서', '정도', '이견', '차', '보', '어떻'],
#  ['소부', '법관', '구성', '있'],
#  ['만장일치', '되', '전원', '합의체', '넘기', '회부', '하'],
#  ['만장일치', '되', '되', '대하', '사실'],
#  ['만장일치', '되', '때', '전원', '합의체', '회부', '있'],
#  ['사회',
#   '이목',
#   '끌',
#   '사건',
#   '대하',
#   '사실',
#   '법관',
#   '하',
#   '자체',
#   '그렇',
#   '결정',
#   '문제',
#   '있',
#   '있',
#   '전원',
#   '합의체',
#   '회부',
#   '판결',
#   '의도',
#   '있',
#   '있',
#   '소부',
#   '만장일치',
#   '되',
#   '있'],
#  ['만장일치',
#   '되',
#   '하',
#   '전원',
#   '합의체',
#   '회부',
#   '있',
#   '개인',
#   '의견',
#   '보',
#   '때',
#   '만장일치',
#   '나오',
#   '같'],
#  ['주심', '판사', '노', '정희', '주심', '이전', '춘천', '사건'],
#  ['그때', '판결', '이유', '같', '똑같', '이유', '무죄', '취지', '파기', '환송', '경우', '있'],
#  ['개인',
#   '보',
#   '때',
#   '아마',
#   '주',
#   '심',
#   '판사',
#   '입장',
#   '파기',
#   '환송',
#   '의지',
#   '가지',
#   '있',
#   '그렇',
#   '보',
#   '그렇',
#   '하',
#   '결과',
#   '오늘',
#   '보',
#   '소수',
#   '의견',
#   '다음',
#   '다수'],
#  ['법관', '인원수', '찬성', '반대', '차이', '그렇', '크'],
#  ['만약', '이중', '의견', '하', '판결', '뒤바뀌', '있', '경우'],
#  ['결과', '이상', '다수', '의견', '되', '이재명', '지사', '살아나', '이렇', '보', '있'],
#  ['말씀', '이렇', '법관', '사이에서', '사회', '사안', '바라보', '시각', '있', '사안', '대법원', '이례'],
#  ['이렇', '선고', '결과', '중계', '게'],
#  ['박근혜', '대통령', '국정', '농', '단', '사건', '이후', '이'],
#  ['그렇'],
#  ['자치', '단체장', '처음', '이재명', '지사'],
#  ['사실', '선고', '대하', '공개', '대하', '규정', '나오', '오래되', '대법원', '자체'],
#  ['이재명',
#   '지사',
#   '대하',
#   '선고',
#   '사실',
#   '유죄',
#   '부분',
#   '대하',
#   '공직',
#   '선거법',
#   '위반',
#   '허위',
#   '사실',
#   '공표',
#   '대하',
#   '사실',
#   '법리',
#   '그렇',
#   '어렵'],
#  ['대법원', '선고', '되', '공개'],
#  ['사회',
#   '이목',
#   '집중',
#   '사건',
#   '보',
#   '있',
#   '이',
#   '선고',
#   '같',
#   '전원',
#   '합의체',
#   '회부',
#   '하',
#   '공개',
#   '하',
#   '있'],
#  ['허위', '사실', '공표', '죄', '관하', '대법원', '법리', '국민', '알리', '하', '측면', '있'],
#  ['그렇', '보'],
#  ['오늘', '이재명', '지사', '대법원', '나오', '대법원', '판결', '같', '경우', '나오', '되'],
#  ['그렇', '일반', '형사', '사건', '심', '심', '선고', '날', '나오', '출석', '하', '하'],
#  ['만약', '출석', '하', '되', '영장', '발부', '하', '되'],
#  ['피고인', '없', '상태', '선고', '하'],
#  ['대부분', '실형', '선고', '하'],
#  ['대법원',
#   '같',
#   '경우',
#   '실질',
#   '심리',
#   '자체',
#   '피고인',
#   '법정',
#   '출석',
#   '하',
#   '심리',
#   '서면',
#   '심리'],
#  ['법률', '심이기', '선고', '때', '피고인', '출석', '되'],
#  ['이재명',
#   '지사',
#   '사실',
#   '쟁점',
#   '되',
#   '허위',
#   '사실',
#   '공표',
#   '죄',
#   '대하',
#   '위헌법률심판',
#   '제청',
#   '신청서',
#   '제출',
#   '대법',
#   '공개',
#   '변론',
#   '신청',
#   '하'],
#  ['그렇', '되', '이렇', '적극', '방어', '보'],
#  ['본인', '입장', '엄청나'],
#  ['경기',
#   '지사',
#   '만약',
#   '대법원',
#   '유죄',
#   '확정',
#   '향후',
#   '본인',
#   '정치',
#   '재기',
#   '없',
#   '상황',
#   '5년',
#   '피선거권',
#   '박탈',
#   '선거',
#   '자금',
#   '정도',
#   '보존'],
#  ['사실',
#   '반환',
#   '하',
#   '입장',
#   '보',
#   '본인',
#   '입장',
#   '절대절명',
#   '사력',
#   '재판',
#   '임하',
#   '없',
#   '상황',
#   '보'],
#  ['하', '있', '방법', '꺼내'],
#  ['통하', '생각', '하'],
#  ['법리', '측면', '심', '유죄', '나오', '변호사', '이재명', '지사', '변호사', '출신'],
#  ['많', '숙고', '공부', '하'],
#  ['오늘', '대법원', '판결', '끌어내', '이렇', '보', '있'],
#  ['마지막', '교수', '내년', '보선', '서울시', '부산시', '곳', '치르'],
#  ['그렇'],
#  ['이번',
#   '경기도지사',
#   '대하',
#   '재판',
#   '자체',
#   '원심',
#   '대하',
#   '파기',
#   '환송',
#   '가',
#   '내년',
#   '경기도지사',
#   '선거',
#   '없',
#   '보',
#   '되',
#   '같'],
#  ['그럼에도', '불구하고', '내년', '선거', '이유', '우리나라', '도시', '단체장', '뽑', '선거'],
#  ['민주당',
#   '소속',
#   '광역',
#   '단체장',
#   '자신',
#   '귀책사유',
#   '인하',
#   '선거',
#   '치르',
#   '상황',
#   '민주당',
#   '입장',
#   '정치',
#   '수세',
#   '몰리',
#   '없'],
#  ['그렇', '하', '귀책사유', '있', '하', '후보'],
#  ['그렇', '없', '이야기', '당', '나오', '겁', '니다'],
#  ['당헌',
#   '그렇',
#   '규정',
#   '있',
#   '내년',
#   '보궐',
#   '선거',
#   '그',
#   '후',
#   '있',
#   '대통령',
#   '선거',
#   '크',
#   '영향',
#   '없',
#   '상황'],
#  ['측면',
#   '보',
#   '경기도지사',
#   '살아나',
#   '경기도지사',
#   '빠지',
#   '내년',
#   '4월',
#   '보궐',
#   '선거',
#   '상당',
#   '정치',
#   '의미',
#   '계속',
#   '이어지',
#   '없',
#   '상황',
#   '같'],
#  ['알'],
#  ['이재명', '경기', '지사', '오늘', '선고', '결과', '회견', '하', '소식', '들어오'],
#  ['기자회견', '장면', '이어지', '뉴스', '전해', '드리', '하'],
#  ['지금', '김광삼', '변호사', '재원', '부산', '가톨릭대', '특', '임', '교수', '이야기', '나누'],
#  ['오늘', '말씀', '고맙습니다']]

# %% [markdown]
# #### **Word2Vec 학습**
#
# gensim에서는 다음과 같이 Word2Vec을 지원한다.
#
# > `sentences` : 단어 토큰화된 문장
# > `size` : Projection Layer의 크기, 임베딩 벡터의 차원
# > `window` : 윈도우 크기
# > `min_count` : 단어의 최소 빈도 수, 이 이하의 빈도를 가지는 단어는 학습하지 않음
# > `workers` : 학습을 위한 프로세스 수
# > `sg` : 0일 경우 CBOW, 1일 경우 Skip-Gram

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=tokenList, size=100, window=5, min_count=1, workers=4, sg=0)

# %% [markdown]
# '선거'를 입력했을 때 의미가 유사한 단어들을 출력합니다.

# %%
model_result = model.wv.most_similar("선거")
model_result
# Out:
# [('이유', 0.3242764472961426),
#  ('지나', 0.30343538522720337),
#  ('교체', 0.30158963799476624),
#  ('말씀', 0.2990836501121521),
#  ('춘천', 0.29199838638305664),
#  ('자신감', 0.2813935875892639),
#  ('사실관계', 0.28133994340896606),
#  ('있', 0.26314792037010193),
#  ('대선', 0.25688642263412476),
#  ('지급', 0.24449597299098969)]

# %% [markdown]
# #### **Skip-Gram**
#
# 중심 단어를 통해 주변에 있는 단어들을 예측하는 방법이다.
# 소량의 학습 데이터에서도 잘 동작하며, 자주 사용하지 않는 희귀한 단어를 예측할 수 있다. 하지만 계산 비용이 크다는 문제점이 있다.
# 마찬가지로 중심 단어에 윈도우를 두고, 윈도우 내의 주변 단어의 임베딩 벡터를 예측한다.

# %%
model = Word2Vec(sentences=tokenList, size=100, window=5, min_count=1, workers=4, sg=1)

# %%
model_result = model.wv.most_similar("선거")
model_result
# Out:
# [('있', 0.8363155126571655),
#  ('하', 0.8078051805496216),
#  ('지사', 0.7888187766075134),
#  ('이번', 0.7623277306556702),
#  ('대법원', 0.753893256187439),
#  ('심', 0.7500892877578735),
#  ('선고', 0.7465951442718506),
#  ('사건', 0.7428316473960876),
#  ('대선', 0.7383707761764526),
#  ('입장', 0.7377241849899292)]

# %% [markdown]
# 기사 본문 내용이 짧기 때문에, 모델을 학습하기에 corpus의 크기가 작다.
# 유사도 또한 상당히 낮다.
# 아래는 수집한 기사 100,000건들을 통해 corpus를 구성하고, Word2Vec 모델을 구축하는 내용이다.

# %%
media_list = os.listdir(PREPROCESSED_PATH)

result = []
forCount = []
for media in media_list:
    media_path = os.path.join(PREPROCESSED_PATH, media)
    article_list= os.listdir(media_path)

    for article in article_list:
        reader = RawTextReader(os.path.join(media_path, article)) 
        content = list(filter(None, reader))
        forCount += [token for sent in content for token in sent.split()]
        result += [sent.split() for sent in content]

# %%
print("전체 token의 개수 : {len}".format(len=len(forCount)))
print("중복되지 않은 token의 개수 : {len}".format(len=len(list(set(forCount)))))
# Out:
# 전체 token의 개수 : 19644153
# 중복되지 않은 token의 개수 : 66456

# %%
START_TOKEN = ['<SOS>']
END_TOKEN = ['<EOS>']

# %%
for idx, i in enumerate(result):
    try:
        i =START_TOKEN + i +END_TOKEN
    except:
        print(idx, type(i), i)

# %%
result = list(map(lambda content : START_TOKEN + content + END_TOKEN, result))

# %%
model = Word2Vec(sentences=result, size=256, window=5, min_count=1, workers=4, sg=1, iter=10)

# %%
model_result = model.wv.most_similar("선거")
model_result
# Out:
# [('총선', 0.6850500106811523),
#  ('선거일', 0.6091201901435852),
#  ('낙선', 0.6031482815742493),
#  ('대선', 0.5916657447814941),
#  ('총선거', 0.5857176184654236),
#  ('재보궐선거', 0.584223210811615),
#  ('후보', 0.5775339603424072),
#  ('투표일', 0.5758824348449707),
#  ('금권', 0.5721417665481567),
#  ('보궐', 0.5661484599113464)]

# %%
model.wv.__getitem__('선거').shape
# Out:
# (256,)

# %%
mkdir_p(MODEL_PATH)

wordvec_path = os.path.join(MODEL_PATH, "word2vec-256.wordvectors")
model_path = os.path.join(MODEL_PATH, 'word2vec-256.model')

word_vectors = model.wv
word_vectors.save(wordvec_path)
model.save(model_path)
