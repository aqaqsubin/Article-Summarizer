# %% [markdown]
# ### **Word2Vec**
#
# 원 핫 인코딩을 사용하면서도 단어 간 유사도를 반영할 수 있도록 단어의 의미를 벡터화하는 방법이다.
#
# *비슷한 위치에서 등장하는 단어들은 비슷한 의미를 가진다*는 분포 가설을 따르는 분산 표현 방법을 사용한다.
#
# 예) '강아지'는 주로 '귀엽다','예쁘다' 등의 단어와 함께 등장하는데, 이러한 내용을 가지는 텍스트를 벡터화하면 이 단어들은 의미적으로 가까운 단어가 된다.
#
# <br>
# Word2Vec에는 다음 두 가지 방식이 있다.
#
# - CBOW(Continous Bag of Words)
# - Skip-Gram

# %% [markdown]
# #### **CBOW(Continous Bag of Words)**
#
# 주변에 있는 단어들을 통해 중간에 있는 단어를 예측하는 방법이다.
# 윈도우를 두고, 윈도우 내의 주변 단어의 벡터로 중심 단어의 벡터를 예측한다.
# Skip-Gram에 비해 몇 배 빠른 훈련이 가능하며, 빈번한 단어를 예측하는 데 더 나은 정확도를 가진다.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os
import re

# %%
BASE_DIR = "/data/TestDir/sample_articles"
ORIGIN_PATH = os.path.join(BASE_DIR,"Origin-Data")
PREPROCESSED_PATH = os.path.join(BASE_DIR,"Preprocessed-Train-Data")
PRETTY_PATH = os.path.join(BASE_DIR,"Pretty-Data")
SWORDS_PATH = os.path.join(BASE_DIR, "StopWordList.txt")

# %%
class RawTextReader:
    def __init__(self, filepath):
        self.filepath = filepath
        self.rgxSplitter = re.compile("/n")

    def __iter__(self):
        for line in open(self.filepath, encoding='utf-8'):
            ch = self.rgxSplitter.split(line)
            for s in ch:
                yield s

# %% [markdown]
# 경향신문 언론사 첫번째 기사를 예시로 전처리된 텍스트를 토큰화 한다.

# %%
media_list = os.listdir(ORIGIN_PATH)

media = media_list[2]
media_path = os.path.join(PREPROCESSED_PATH, media)
article_list= os.listdir(media_path)

article = article_list[0]
reader = RawTextReader(os.path.join(media_path, article))
    
content = list(filter(None, reader))
content
# Out:
# ['진행',
#  '강진원 앵커 박상연 앵커 출연',
#  '김광삼 변호사 차재원 부산가톨릭대 특임교수 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 내용은 방송으로 확인하시기 바랍니다',
#  '대법원의 선고 결과 이재명 경기지사와 관련한 대법원의 선고 결과 관련해서 전문가와 함께 자세한 내용 짚어보겠습니다',
#  '변호사님 일단 먼저 주문을 있는 그대로 제가 한번 읽어드릴게요',
#  '다수의견에 따라서 다음과 같이 판결한다',
#  '원심 판결 중 유무죄 부분을 포함한 유죄 부분을 파기하고 이 부분 사건을 수원고등법원에 환송한다',
#  '결국은 허위사실공표 관련된 내용을 무죄 취지로 파기환송한다 이렇게 봐야겠죠',
#  '정확히 말씀하셨고요',
#  '무죄 취지로 파기환송을 했기 때문에 이건 다시 서울고등법원에서 재판을 다시 하게 됩니다',
#  '그런데 대법원에서 이미 무죄 취지였기 때문에 서울고등은 그 취지에 귀속이 될 수밖에 없어요',
#  '그러면 결과적으로 이재명 지사는 수원고등에서 무죄판결을 받게 될 것이다 이렇게 볼 수 있고요',
#  '거기에 대해서 만약에 검찰이 재상고를 하게 되면 대법원에서 다시 재판을 받게 되겠지만 그건 그렇게 결과에 영향을 미치는 그런 선고는 나오지 않을 것이다 이렇게 볼 수 있는 것이죠',
#  '실익이 없는 거죠 검찰 입장에서는',
#  '맞습니다',
#  '사실 일각에서는 이 사건이 전원합의체로 넘어간 것 자체가 이 지사에게 긍정적일 수 있다 이런 시각이 있지 않았습니까',
#  '맞습니다',
#  '전원합의체로 넘어갔고 그리고 또 이례적으로 생중계를 대법원에서 결정하지 않았습니까',
#  '그렇기 때문에 많은 전문가들은 아마 2심의 결과하고 반대되는 결과를 냈기 때문에 상당히 그런 차원에서 대법원이 이런 부분을 널리 홍보하고 싶었던 것이 아닐까 하는 생각이 들었다는 것이고 그리고 또 오늘 전원합의체의 다수 의견 자체가 허위사실공표죄의 새로운 판례를 확립했다',
#  '그런 측면에서라도 이런 부분들을 적극적으로 알리고 싶어 하는 그런 부분들이 반영됐을 것이라는 차원에서 이재명 지사에 대한 무죄 선고 자체를 상당히 강도 높게 예측하던 그런 순간이었습니다',
#  '이재명 경기지사 같은 경우는 여권의 유력한 차기 대선주자로도 꼽혔던 인물이었기 때문에 오늘 선고 결과에 대한 관심이 정치권에서도 뜨거웠습니다',
#  '그래서 정치권 반응도 지금 나온 것 같은데 국회 연결해서 알아보겠습니다',
#  '오늘 판결에 대한 정치권 반응 정리해 주시죠',
#  '우선 더불어민주당은 한숨 돌린 분위기입니다',
#  '이 지사는 여권 대권 가도 1위인 이낙연 의원을 뒤쫓는 가장 강력한 경쟁자입니다',
#  '그래서 만약 이 지사가 원심 확정 판결을 받았다면 내후년 대통령 선거에 출마할 수 없게 돼 민주당으로선 또 대선 후보를 잃게 될 위기였는데요',
#  '유력 대선 주자였던 안희정 전 충남지사와 박원순 전 서울시장까지 낙마한 상황에서 차기 대권 구도에 적신호가 켜지는 것 아니냐 이런 우려도 나왔습니다',
#  '하지만 무죄 취지의 파기환송 결정이 나면서 이런 걱정을 깨끗이 씻게 됐습니다',
#  '이 지사 역시 정치적 위기에서 벗어나면서 남은 2년 동안 도정을 안정적으로 운영할 동력을 얻게 됐습니다',
#  '이와 함께 이낙연 의원을 뒤쫓으며 차기 대권 지지율도 상승세인 만큼 이후 대선 행보에도 청신호가 켜졌다는 분석입니다',
#  '또 서울과 부산 시장에 이어 경기도지사까지 빈자리가 되는 초유의 상황도 피할 수 있게 됐습니다',
#  '이에 대해 미래통합당 반응은 어떻습니까',
#  '통합당은 일단 대법원 판결에 물음표를 그렸습니다',
#  '사법부의 판결을 존중하는 게 마땅하지만 법과 법관의 양심에 근거한 객관적이고 냉철한 판단인지 여전히 의문이라는 겁니다',
#  '그러면서 경기도민들은 친형 정신병원 강제입원과 허위사실 유포 의혹 등의 혐의로 얼룩진 이 지사의 권한 행사를 계속 지켜봐야 한다며 법리적으로 무죄를 선고했지만 정치적으로는 유죄라고 밝혔습니다',
#  '다만 부산과 서울에 이어 경기도까지는 수장 공백 사태가 오지 않았다는 점은 다행이라고 말했는데요',
#  '만약 이 지사가 자리를 잃게 됐더라면 통합당이 내년 4월 보궐선거에서 정부 심판론을 넘어 정권 교체론까지 몰아갈 것이란 전망도 나왔습니다',
#  '경기 지사직은 빠졌지만 내년 보궐선거는 서울과 부산시장을 두고 사실상 대선 전초전으로 치러집니다',
#  '민주당은 당장 후보를 낼지 말지부터 고민에 빠진 모습인데요',
#  '반면 통합당은 서울시장과 부산시장 보궐선거에 낙관적인 측면이 있다고 말하며 강한 자신감을 드러내고 있습니다',
#  '지금까지 국회에서 전해드렸습니다',
#  '정치권 반응을 알아봤습니다',
#  '앞으로의 이재명 지사의 정치 인생에 대해서도 짚어보지 않을 수가 없는데 정치권이 이번 선고 결과를 예의주시한 이유가 있을 겁니다',
#  '아무래도 여권의 유력한 대권주자이기 때문 아니겠습니까',
#  '그렇죠',
#  '이재명 지사는 여권 잠재주자 중에서 2위를 달리고 있고요',
#  '상당히 지지세가 급상승세를 그리고 있는 상황입니다',
#  '그리고 여기다가 박원순 시장의 우리가 전혀 예상치 못한 극단적인 선택 이런 것 때문에 여권의 잠재주자들이 상당히 한 명 한 명씩 사라진 상황에서 만약에 이재명 지사까지 낙마했을 경우에 내년 민주당 내에서의 대권 경선 자체가 상당히 어떻게 보면 이낙연 주자 혼자의 홀로경선이 될 가능성이 높았다',
#  '그렇다고 한다면 흥행에도 찬물을 끼얹을 수밖에 없었던 상황',
#  '그리고 께서도 리포트를 했지만 민주당 입장에서도 상당히 집권여당 입장에서도 안도의 한숨을 내쉴 수밖에 없다',
#  '부산에 이어서 서울까지',
#  '그리고 여기다 경기지사까지 낙마했을 경우에는 집권여당으로서의 책임도 있지만 그리고 내년 보궐선거에서 전국 3개의 가장 큰 광역단체에서의 선거가 이루어지는 상황에서 상당한 부담을 가질 수밖에 없었을 것인데 이러한 부분을 모면할 수 있다',
#  '아무래도 무엇보다 이번 결정에서 가장 반길 사람은 이재명 지사겠죠',
#  '이재명 지사는 사실 우리 정치권에서 입지전적인 인물로 알려져 있습니다마는 여기에다 하나 더 이미지를 추가한 것 같아요',
#  '오뚝이 이미지까지',
#  '사실 이재명 지사가 여기까지 오는 과정에서 여러 가지 정치적 고난을 겪지 않았습니까',
#  '그리고 특히 지난 경기지사 선거와 관련해서 자신에게 주어졌던 상당한 걸림돌 중에 크게 두 가지가 있었는데 첫 번째가 여배우 스캔들',
#  '여배우 스캔들은 일단 무혐의가 되면서 경찰 단계에서 끝났습니다마는 두 번째 남은 것이 바로 친형 강제입원과 관련된 논란이었는데 이 부분도 지금 대법원에서 완전하게 클리어하게 정리됨으로써 본인 입장에서는 정치적 추세가 완전히 풀렸다',
#  '그렇다고 한다면 급상승을 그리고 있는 지지율에 그리고 또 변화된 여권의 구도 차기 대권구도 자체가 상당히 자기에게 유리한 쪽으로 진행될 수 있다',
#  '그렇다는 측면에서 본다면 이재명 지사 입장에서는 상당히 이제는 큰 날개를 펴면서 웅비의 한 순간을 맞이할 수도 있다는 전망도 나올 수 있는 상황인 것 같습니다',
#  '정치권도 숨 가쁘게 여러 판단을 내릴 것 같은데 오늘 선고와 관련해서 이재명 경기도지사의 변호인측 입장이 조금 전 들어왔습니다',
#  '직접 들어보겠습니다',
#  '지금까지 이재명 경기도지사 변호인 측의 오늘 대법원 선고 결과에 대한 입장 들었습니다',
#  '그럼 지금부터 차근차근 선고 취지에 대해서 전문가와 함께 들어보도록 하겠습니다',
#  '변호사님 오늘 무죄 취지로 사건을 파기환송한 것이지 않습니까 허위사실공표 부분에 대해서',
#  '저희도 같이 함께 생중계로 들었는데 핵심은 이거였던 것 같아요',
#  '후보자 토론회 과정에서 즉흥적인 진행으로 명확성에 한계가 있고 토론의 자유를 보장해야 된다 이런 취지였던 것 같은데 구체적으로 내용을 설명해 주시죠',
#  '전체적인 것은 그런 취지였고요',
#  '일단 후보자 토론회 방송 후보자 토론회는 굉장히 시간적 제약이 있잖아요',
#  '1분이면 1분 답할 시간을 그렇게 주고 굉장히 숨가쁘게 돌아가죠',
#  '그래서 여러 가지 제약이 있고 그다음에 사실 방송 토론을 하다 보면 준비된 원고에서 할 수가 없어요',
#  '그래서 굉장히 즉흥적인 면이 있는데 하다 보면 표현이 명확하지 않은 경우도 있고요',
#  '또 자신의 처한 입장을 어떻게 보면 변호하는 그런 상황이 될 수 있지 않습니까',
#  '그래서 대법원에서는 그런 것 같아요',
#  '어떠한 표현을 부정확하게 또 아니면 바람직하게 표현했다고 해서 이것 자체를 법적으로 처벌하는 것 자체는 방송토론이랄지 아니면 선거운동을 굉장히 제약하게 된다',
#  '그러면 궁극적으로 말하자면 선거운동 자체의 본질을 침해하는 것이 아니냐',
#  '그런 대법원의 판결 이유 같고요',
#  '그래서 결론적으로 이야기하면 어떤 의도적으로 적극적으로 왜곡했다거나 의도적으로 했다면 모르겠지만 해명하는 차원에서 했다고 한다면 이건 허위사실공표로 볼 수 없다',
#  '그래서 공표 자체를 약간 적극적 의미로 해석하는 겁니다',
#  '설사 일부에 있어서 사실이 다르다 하더라도 해명하는 과정에서 거기에 대해서 굉장히 소극적으로 대답을 했다고 하면 공표라고 볼 수 없다 이렇게 보는 것 같고요',
#  '물론 이전에도 유사한 대법원 판결이 있지만 이번 판결 자체는 전원합의체에서 했다는 의미가 있고요',
#  '사실 허위사실공표와 관련해서는 굉장히 허위사실공표 이게 추상적인 개념이거든요',
#  '그렇지만 오늘 전원합의체 판결에서 허위사실과 관련된 한계 특히 방송토론회에서의 한계하고 공표의 의미 자체가 상당히 적극성을 띄어야 한다 그런 의미로 선고를 했기 때문에 향후에 있어서 허위사실공표와 관련된 부분이 상당 부분 정리가 됐다고 봐요',
#  '그래서 무자비 고소고발을 일삼는다랄지 아니면 지금 이재명 지사에 관한 판결도 1심에서 무죄 2심에서 유죄가 나왔단 말이에요',
#  '그러니까 어떻게 보면 법을 전문적으로 하는 판사 자체도 굉장히 이 부분에 대해서 다른 시각을 가지고 있었잖아요',
#  '그런데 오늘 전원합의체 판결이 그 부분에서 상당히 명확하게 해석해 주었다 이렇게 판단해 볼 수가 있습니다',
#  '이후 절차에 대해서도 한번 살펴보겠습니다',
#  '앞서 간단하게 말씀하시기는 했는데 오늘 대법원은 원심을 무죄 취지로 어떻게 보면 파기하고 사건을 수원고등법원으로 돌려보냈습니다',
#  '결국 수원고법에서 파기환송심이 진행될 예정인데 대법원의 선고결과에 귀속되니까 무죄 취지의 판결이 나올 가능성이 높은 거죠 결국은',
#  '그렇죠',
#  '그리고 파기환송심 재판이 오래 걸리지 않을 거예요',
#  '왜냐하면 이 사건이 2019년부터 시작됐잖아요',
#  '그리고 1심과 2심을 통해서 엄청나게 치열한 공방을 했고 결국 대법원 판결까지 왔는데 증거랄지 사실관계는 거의 다 명확하게 정리가 됐다',
#  '또 그 부분에 대해서도 사실은 검찰에서 뭔가 이의제기를 해서 새로운 증거를 낼 수 있는 것들이 없어요',
#  '그리고 지금 대법원의 판단 자체는 법률적 해석에 관한 판단입니다',
#  '법률적 해석을 검찰측에서 다르게 한다고 해도 이걸 어떻게 보면 뒤집을 수 없거든요',
#  '그러면 다른 파기환송심 이재용 부회장이랄지 아니면 최서원 씨 판결 박근혜 전 대통령에 대한 파기환송과는 다르게 파기환송심이 수원고등에서 이루어지게 되는데 그 절차는 상당히 신속하게 진행될 가능성이 크다',
#  '왜냐하면 법률적 해석에 관해서만 정리를 하면 되니까요',
#  '그러면 결국 검찰이 재상고의 대상이 되지만 다른 사건에 비해서는 시간적인 것은 많이 걸리지 않는다',
#  '그러면 물론 오늘 전원합의체 판결로 이재명 지사가 완전히 자유로워졌다고 볼 수 있는 거죠',
#  '그렇지만 향후 대법원까지 다시 재상고된다 하더라도 이재명 지사가 정치활동을 하는 데는 아무런 제약이 없다 이렇게 보면 됩니다',
#  '최종 결론이 나올 때까지 시간은 오래 걸리지 않을 것이다라는 말씀을 해 주셨고요',
#  '정치권 파장에 대해서도 계속 얘기를 나눠보겠습니다',
#  '앞서 교수님께서 말씀해 주신 것처럼 최근 이 지사의 지지도가 많이 오르는 모습이었는데 이낙연 의원에 대해서도 말씀을 해 주셨고요',
#  '이낙연 의원과 이재명 지사',
#  '그럼 지지도나 이런 게 어떻게 예상이 될까요',
#  '일단 이재명 지사가 급상승세의 지지율을 보인 이유가 이번 코로나 사태와 관련해서 상당한 나름대로의 정치적 순발력을 통해서 상당히 국민들에게 다가가는 행정가의 모습을 보였다는 겁니다',
#  '예를 들면 코로나에 대해서 신천지에 대한 강제명령 이런 부분들',
#  '그리고 코로나 사태에서 비롯된 여러 가지 경제적인 어려움들 때문에 재난에 대한 기본소득을 주장하면서 사실상 재난지원금이 100 국민들에게 다 지급되는 데 어떻게 보면 물꼬를 튼 측면',
#  '그리고 그에 이어서 지금은 기본소득에 대한 이야기까지 이야기하면서 상당히 여러 가지 국정 현안에 대해서 아젠다를 주도하는 모습을 보이고 있다는 겁니다',
#  '그러한 상황에서 사실 어떻게 보면 정치적인 족쇄였던 지난 경기지사 선거 때의 법률적 문제가 완전히 해소가 되면 이제는 걸림돌이 사라진 것 아니겠습니까',
#  '그렇다고 한다면 본인의 이러한 정치적인 공간이 넓어진 측면',
#  '그리고 상승세에 있는 지지율을 바탕으로 해서 아무래도 좀 더 공격적인 행보를 할 가능성이 높다',
#  '물론 대법원 판결이 나오기 전에는 이런 이야기도 했습니다',
#  '자신의 향후 정치 역점과 관련해서 대선 도전에 대해서는 상당히 조심스러운 태도를 보였어요',
#  '지금 내 목이 날아가느냐 이 상황인데 그렇기 때문에 대선보다는 경기도지사 재선에 방점을 두는 듯한 모습을 보이기는 했습니다마는 이제는 상황이 완전히 달라졌거든요',
#  '그렇다고 한다면 본인 입장에서 좀 더 공격적인 상당히 적극적인 행보를 하지 않을까',
#  '사실 벌써 이번 코로나 사태 직후에 본인이 공격적인 모습을 보이고 있는 것 중 하나가 예를 들면 친문계 인사를 영입했고요',
#  '그리고 또 이번 대북전단 사건 관련해서 통일부가 주춤주춤하고 있을 때 이 부분도 적극적으로 뭔가 해서 예를 들면 여권 지지층으로부터 강한 결집을 받아내는 그런 모습들이 보였거든요',
#  '그렇다고 해서 그러면 모든 것이 앞으로 다 전도유망하게 무조건 갈 수 있느냐',
#  '꼭 그렇지도 않을 겁니다',
#  '왜냐하면 사실 이재명 지사가 법률적으로는 클리어됐지만 아직까지도 강력한 친문 지지층들과의 정치적 앙금은 그대로 남아 있다는 겁니다',
#  '과거 경기지사 사건 때 여러 가지 논란들이 많지 않았습니까',
#  '그때 친문 세력들과 이재명 지사와의 정치적인 갈등들을 과연 얼마만큼 본인 스스로가 털고 화해하고 나갈 수 있느냐',
#  '그리고 또 하나는 이번 전당대회가 8월에 있지 않습니까',
#  '8월달 전당대회 아마도 이낙연 의원이 강력한 당권주자로서 급부상하고 있는데 이낙연 지사가 물론 내년 3월까지로 한정돼있습니다마는 당권을 장악해서 예를 들어서 당내 조직을 확보했을 경우에는 내년 경선 자체가 아무래도 당내 조직에서 열세인 이재명 지사가 감당하기는 부담스러울 수 있다 그런 전망이 있습니다마는 모르겠습니다',
#  '일단 본인이 여러 가지를 생각해서 아마 정책적 행보는 적극적으로 할 가능성이 저는 높다고 봅니다',
#  '통합당의 셈법도 복잡해질 것 같은데 어떻습니까',
#  '그렇죠 통합당 입장에서는 사실 이번 판결에 대해서는 상당히 유감의 뜻을 표하고 있습니다마는 무엇보다도 이재명 지사가 이번에 대권주자로 다시 살아났다는 측면을 가장 위협적으로 느끼지 않을까 하는 생각이 듭니다',
#  '앞서 제가 말씀드린 대로 이재명 지사가 만에 하나 낙마하는 경우가 됐다고 한다면 일단 여당의 경선 자체가 상당히 흥행적 요소가 사라질 가능성이 높다',
#  '그렇다고 한다면 이낙연 의원이 단독으로 만약에 추대됐을 경우에는 본선에 쉽게 올라갈 수 있다고 볼 수 있지만 그러나 당내 경선이 치열해지면 치열해질수록 누가 되든지 간에 본선 후보가 상당한 경쟁력을 가질 수 있다',
#  '그런 측면에서 본다고 하면 미래통합당 입장에서도 차기 대선에서 내세울 수 있는 후보를 상당히 좀 더 엄정하게 선임할 수밖에 없는 상황이다',
#  '그러나 당장 우리가 알다시피 미래통합당에서 차기 대선주자와 관련해서 풀에 한계가 있다',
#  '그런 측면에서 새로운 인물 새로운 시대정신을 가진 사람을 발굴해내야 되는 그런 정치적 과제가 훨씬 더 무거워진 것이 아닐까 하는 생각이 듭니다',
#  '이번 사건은 다수 의견을 따르는 전원합의체 판단에 따라서 원심의 유죄 선고 부분이 무죄 취지로 파기환송됐습니다',
#  '조금 전에 열렸던 대법원 선고 핵심 내용을 다시 한 번 들어보시겠습니다',
#  '대법원장의 오늘 주요 선고 취지에 대해서 다시 한 번 들었습니다',
#  '변호사님 앞서 계속 말씀드리고 있는데 오늘 대법원 선고도 다수의견과 소수의견이 갈렸지 않습니까',
#  '그런데 원래 이게 대법원 대법관들 소부에 회부가 됐었는데 소부에서는 결국 만장일치로 의견일치를 봐야 되는데 의견일치가 안 돼서 결국 전원합의체로 넘어간 거잖아요',
#  '그만큼 대법관들 사이에서도 어느 정도 이견차가 있었다고 봐야겠습니까 어떻겠습니까',
#  '일단 소부는 대법관이 4명으로 구성되어 있습니다',
#  '그래서 여기서 만장일치가 안 되면 전원합의체로 넘기는데 회부한다고 하죠',
#  '그런데 지금 만장일치가 됐는지 안 됐는지에 대해서는 사실 정확하지 않아요',
#  '왜냐하면 만장일치가 안 됐을 때 전원합의체에 회부할 수도 있고요',
#  '아니면 이처럼 굉장히 사회적 이목을 끄는 사건에 대해서는 사실 4명의 법관이 하는 것 자체는 그렇게 결정하는 것은 문제가 있을 수 있기 때문에 전원합의체에 회부해서 이걸 명확하게 판결하려는 그런 의도가 있을 수 있기 때문에 소부에서 만장일치가 안 됐을 수도 있고요',
#  '아니면 만장일치가 됐다 하더라도 전원합의체로 회부될 수 있는데 저는 개인적 의견으로 볼 때 아마 만장일치가 안 나왔던 것 같아요',
#  '그리고 주심 판사였던 노정희 주심이 이전에도 이와 굉장히 유사한 춘천 사건이 하나 있었거든요',
#  '그때도 지금 판결 이유와 같은 똑같은 이유로 무죄 취지의 파기환송을 한 경우가 있거든요',
#  '그래서 저는 개인적으로 볼 때 아마 주심 판사의 입장은 굉장히 파기환송의 확고한 의지를 가지고 있을 것이다 그렇게 봤었고 그런다고 한다면 결과적으로 오늘 보니까 소수 의견이 다섯 분이고 그다음에 다수가 일곱 분이었거든요',
#  '그러니까 법관 인원수에서 찬성과 반대의 차이가 그렇게 크지 않았어요',
#  '만약에 이중에 한 명만 다른 의견이 있었다고 한다면 판결이 뒤바뀔 수도 있는 그런 경우가 있었기 때문에',
#  '그렇지만 결과적으로 7명 이상이 다수 의견이 됐기 때문에 결국 이재명 지사는 살아날 수 있었다 이렇게 볼 수 있는 거죠',
#  '말씀하신 대로 이렇게 대법관 사이에서 그리고 우리 사회에서 이 사안을 바라보는 여러 시각이 있기 때문에 그리고 중요한 사안이기 때문에 대법원에서도 이례적이지 않습니까',
#  '이렇게 선고 결과를 생중계하는 게',
#  '박근혜 전 대통령 국정농단 사건 이후에 두 번째인 거잖아요 이게',
#  '그렇죠',
#  '자치단체장으로는 처음입니다 이재명 지사가',
#  '그래서 사실 선고에 대한 공개 그것에 대해서는 규정이 나온 건 오래되지 않았어요 대법원 자체에서',
#  '그런데 이재명 지사에 대해서 선고가 사실은 유죄 부분에 대한 공직선거법 위반 허위사실공표에 대해서 사실 법리가 그렇게 어려운 건 아닙니다',
#  '그러면 대법원에서 그냥 선고하면 되는데 왜 이걸 공개했을까',
#  '그건 첫 번째 사회적 이목을 집중시키는 사건이라고 볼 수 있고 또 하나는 이게 너무 간단하게 선고할 것 같으면 전원합의체에 회부됐다 하더라도 공개 안 할 수도 있는 거거든요',
#  '그런데 허위사실공표죄에 관해서 대법원의 법리적인 것 그런 것들을 명확하게 국민에게 알리고 싶어 하는 그런 측면도 있지 않았을까',
#  '저는 그렇게 봅니다',
#  '오늘 이재명 지사는 대법원에 나오지 않았는데 대법원 판결 같은 경우는 굳이 안 나와도 되는 거죠',
#  '그렇죠 일반적인 형사사건은 1심이나 2심에서는 반드시 선고날 나와서 출석을 해야 합니다',
#  '그리고 만약에 출석을 계속 안 하게 되면 영장발부를 하게 돼요',
#  '아니면 피고인이 없는 상태에서 선고를 하죠',
#  '그러면 대부분 실형 선고를 하거든요',
#  '그렇지만 대법원 같은 경우는 실질적으로 심리 자체가 피고인이 법정에 출석해서 하는 심리가 아니고 서면심리거든요',
#  '그리고 더군다나 법률심이기 때문에 선고 때 피고인은 출석하지 않아도 됩니다',
#  '이재명 지사는 사실 앞서 쟁점이 되는 허위사실공표죄에 대한 위헌법률심판제청신청서를 제출했고 또 대법 공개변론 신청도 했잖아요',
#  '그렇게 되면 이렇게 적극적으로 방어했다고 볼 수 있겠죠',
#  '본인 입장에서는 엄청난 일이죠',
#  '더구나 경기지사를 만약에 대법원에서 유죄가 확정돼 버리면 일단 향후 본인의 정치는 더 재기할 수 없는 상황일 뿐만 아니라 더군다나 5년간 또 피선거권이 박탈되고 또 지금 선거자금이 38억 정도가 보존됐거든요',
#  '그러면 그것도 사실은 다시 반환해야 하는 그런 입장이기 때문에 어찌 보면 본인 입장에서는 절대절명이고 아무튼 사력을 다해서 이 재판에 임할 수밖에 없는 그런 상황이었다고 봅니다',
#  '그래서 할 수 있는 방법은 모두 꺼냈다',
#  '그래서 결국 이러한 것들이 통하지 않았나 저는 그런 생각을 합니다',
#  '그리고 법리적인 측면에서도 2심에서 유죄가 나왔지만 아마 변호사랄지 아니면 이재명 지사도 변호사 출신 아닙니까',
#  '굉장히 많은 숙고와 공부를 했을 것이다',
#  '그래서 오늘 대법원 판결을 끌어냈다 이렇게 볼 수도 있는 거죠',
#  '마지막으로 교수님 내년 재보선은 서울시와 부산시 두 곳에서 치러지는 거죠',
#  '그렇죠',
#  '지금 아무래도 이번 경기도지사에 대한 재판 자체가 상당히 원심에 대한 파기환송으로 갔기 때문에 내년 경기도지사 선거는 없는 걸로 봐야 될 것 같고요',
#  '그럼에도 불구하고 내년 선거가 상당히 중요한 이유가 우리나라 제1 2도시에서의 단체장을 뽑는 선거 아닙니까',
#  '그럼 무엇보다도 지금 민주당 소속의 광역단체장들이 자신들의 여러 가지 귀책사유로 인해서 지금 현재 선거가 치러지는 상황이기 때문에 민주당 입장에서는 상당히 정치적 수세에 몰릴 수밖에 없다',
#  '그렇다고 해서 그러면 귀책사유가 있다고 해서 후보를 내지 않을 것이냐',
#  '또 그럴 수도 없다는 이야기들을 당 내에서 나온다는 겁니다',
#  '물론 당헌에는 그렇게 규정되어 있지만 지금 내년 보궐선거가 그 후년에 있는 대통령 선거에 상당히 큰 영향을 줄 수밖에 없는 상황이다',
#  '그런 측면에서 보면 지금 경기도지사는 일단 살아남으로써 경기도지사는 빠졌지만 내년 4월 보궐선거는 상당한 정치적 의미가 계속적으로 이어질 수밖에 없는 상황인 것 같습니다',
#  '알겠습니다',
#  '이재명 경기지사가 오늘 선고 결과에 회견을 한다는 소식도 들어왔습니다',
#  '기자회견 장면은 이어지는 뉴스에서 전해 드리도록 하겠습니다',
#  '지금까지 김광삼 변호사 차재원 부산가톨릭대 특임교수와 함께 이야기 나눴습니다',
#  '오늘 말씀 고맙습니다']

# %%
tokenList = [sent.split() for sent in content]
tokenList
# Out:
# [['진행'],
#  ['강진원', '앵커', '박상연', '앵커', '출연'],
#  ['김광삼',
#   '변호사',
#   '차재원',
#   '부산가톨릭대',
#   '특임교수',
#   '아래',
#   '텍스트는',
#   '실제',
#   '방송',
#   '내용과',
#   '차이가',
#   '있을',
#   '수',
#   '있으니',
#   '보다',
#   '정확한',
#   '내용은',
#   '방송으로',
#   '확인하시기',
#   '바랍니다'],
#  ['대법원의',
#   '선고',
#   '결과',
#   '이재명',
#   '경기지사와',
#   '관련한',
#   '대법원의',
#   '선고',
#   '결과',
#   '관련해서',
#   '전문가와',
#   '함께',
#   '자세한',
#   '내용',
#   '짚어보겠습니다'],
#  ['변호사님', '일단', '먼저', '주문을', '있는', '그대로', '제가', '한번', '읽어드릴게요'],
#  ['다수의견에', '따라서', '다음과', '같이', '판결한다'],
#  ['원심',
#   '판결',
#   '중',
#   '유무죄',
#   '부분을',
#   '포함한',
#   '유죄',
#   '부분을',
#   '파기하고',
#   '이',
#   '부분',
#   '사건을',
#   '수원고등법원에',
#   '환송한다'],
#  ['결국은', '허위사실공표', '관련된', '내용을', '무죄', '취지로', '파기환송한다', '이렇게', '봐야겠죠'],
#  ['정확히', '말씀하셨고요'],
#  ['무죄',
#   '취지로',
#   '파기환송을',
#   '했기',
#   '때문에',
#   '이건',
#   '다시',
#   '서울고등법원에서',
#   '재판을',
#   '다시',
#   '하게',
#   '됩니다'],
#  ['그런데',
#   '대법원에서',
#   '이미',
#   '무죄',
#   '취지였기',
#   '때문에',
#   '서울고등은',
#   '그',
#   '취지에',
#   '귀속이',
#   '될',
#   '수밖에',
#   '없어요'],
#  ['그러면',
#   '결과적으로',
#   '이재명',
#   '지사는',
#   '수원고등에서',
#   '무죄판결을',
#   '받게',
#   '될',
#   '것이다',
#   '이렇게',
#   '볼',
#   '수',
#   '있고요'],
#  ['거기에',
#   '대해서',
#   '만약에',
#   '검찰이',
#   '재상고를',
#   '하게',
#   '되면',
#   '대법원에서',
#   '다시',
#   '재판을',
#   '받게',
#   '되겠지만',
#   '그건',
#   '그렇게',
#   '결과에',
#   '영향을',
#   '미치는',
#   '그런',
#   '선고는',
#   '나오지',
#   '않을',
#   '것이다',
#   '이렇게',
#   '볼',
#   '수',
#   '있는',
#   '것이죠'],
#  ['실익이', '없는', '거죠', '검찰', '입장에서는'],
#  ['맞습니다'],
#  ['사실',
#   '일각에서는',
#   '이',
#   '사건이',
#   '전원합의체로',
#   '넘어간',
#   '것',
#   '자체가',
#   '이',
#   '지사에게',
#   '긍정적일',
#   '수',
#   '있다',
#   '이런',
#   '시각이',
#   '있지',
#   '않았습니까'],
#  ['맞습니다'],
#  ['전원합의체로', '넘어갔고', '그리고', '또', '이례적으로', '생중계를', '대법원에서', '결정하지', '않았습니까'],
#  ['그렇기',
#   '때문에',
#   '많은',
#   '전문가들은',
#   '아마',
#   '2심의',
#   '결과하고',
#   '반대되는',
#   '결과를',
#   '냈기',
#   '때문에',
#   '상당히',
#   '그런',
#   '차원에서',
#   '대법원이',
#   '이런',
#   '부분을',
#   '널리',
#   '홍보하고',
#   '싶었던',
#   '것이',
#   '아닐까',
#   '하는',
#   '생각이',
#   '들었다는',
#   '것이고',
#   '그리고',
#   '또',
#   '오늘',
#   '전원합의체의',
#   '다수',
#   '의견',
#   '자체가',
#   '허위사실공표죄의',
#   '새로운',
#   '판례를',
#   '확립했다'],
#  ['그런',
#   '측면에서라도',
#   '이런',
#   '부분들을',
#   '적극적으로',
#   '알리고',
#   '싶어',
#   '하는',
#   '그런',
#   '부분들이',
#   '반영됐을',
#   '것이라는',
#   '차원에서',
#   '이재명',
#   '지사에',
#   '대한',
#   '무죄',
#   '선고',
#   '자체를',
#   '상당히',
#   '강도',
#   '높게',
#   '예측하던',
#   '그런',
#   '순간이었습니다'],
#  ['이재명',
#   '경기지사',
#   '같은',
#   '경우는',
#   '여권의',
#   '유력한',
#   '차기',
#   '대선주자로도',
#   '꼽혔던',
#   '인물이었기',
#   '때문에',
#   '오늘',
#   '선고',
#   '결과에',
#   '대한',
#   '관심이',
#   '정치권에서도',
#   '뜨거웠습니다'],
#  ['그래서', '정치권', '반응도', '지금', '나온', '것', '같은데', '국회', '연결해서', '알아보겠습니다'],
#  ['오늘', '판결에', '대한', '정치권', '반응', '정리해', '주시죠'],
#  ['우선', '더불어민주당은', '한숨', '돌린', '분위기입니다'],
#  ['이',
#   '지사는',
#   '여권',
#   '대권',
#   '가도',
#   '1위인',
#   '이낙연',
#   '의원을',
#   '뒤쫓는',
#   '가장',
#   '강력한',
#   '경쟁자입니다'],
#  ['그래서',
#   '만약',
#   '이',
#   '지사가',
#   '원심',
#   '확정',
#   '판결을',
#   '받았다면',
#   '내후년',
#   '대통령',
#   '선거에',
#   '출마할',
#   '수',
#   '없게',
#   '돼',
#   '민주당으로선',
#   '또',
#   '대선',
#   '후보를',
#   '잃게',
#   '될',
#   '위기였는데요'],
#  ['유력',
#   '대선',
#   '주자였던',
#   '안희정',
#   '전',
#   '충남지사와',
#   '박원순',
#   '전',
#   '서울시장까지',
#   '낙마한',
#   '상황에서',
#   '차기',
#   '대권',
#   '구도에',
#   '적신호가',
#   '켜지는',
#   '것',
#   '아니냐',
#   '이런',
#   '우려도',
#   '나왔습니다'],
#  ['하지만', '무죄', '취지의', '파기환송', '결정이', '나면서', '이런', '걱정을', '깨끗이', '씻게', '됐습니다'],
#  ['이',
#   '지사',
#   '역시',
#   '정치적',
#   '위기에서',
#   '벗어나면서',
#   '남은',
#   '2년',
#   '동안',
#   '도정을',
#   '안정적으로',
#   '운영할',
#   '동력을',
#   '얻게',
#   '됐습니다'],
#  ['이와',
#   '함께',
#   '이낙연',
#   '의원을',
#   '뒤쫓으며',
#   '차기',
#   '대권',
#   '지지율도',
#   '상승세인',
#   '만큼',
#   '이후',
#   '대선',
#   '행보에도',
#   '청신호가',
#   '켜졌다는',
#   '분석입니다'],
#  ['또',
#   '서울과',
#   '부산',
#   '시장에',
#   '이어',
#   '경기도지사까지',
#   '빈자리가',
#   '되는',
#   '초유의',
#   '상황도',
#   '피할',
#   '수',
#   '있게',
#   '됐습니다'],
#  ['이에', '대해', '미래통합당', '반응은', '어떻습니까'],
#  ['통합당은', '일단', '대법원', '판결에', '물음표를', '그렸습니다'],
#  ['사법부의',
#   '판결을',
#   '존중하는',
#   '게',
#   '마땅하지만',
#   '법과',
#   '법관의',
#   '양심에',
#   '근거한',
#   '객관적이고',
#   '냉철한',
#   '판단인지',
#   '여전히',
#   '의문이라는',
#   '겁니다'],
#  ['그러면서',
#   '경기도민들은',
#   '친형',
#   '정신병원',
#   '강제입원과',
#   '허위사실',
#   '유포',
#   '의혹',
#   '등의',
#   '혐의로',
#   '얼룩진',
#   '이',
#   '지사의',
#   '권한',
#   '행사를',
#   '계속',
#   '지켜봐야',
#   '한다며',
#   '법리적으로',
#   '무죄를',
#   '선고했지만',
#   '정치적으로는',
#   '유죄라고',
#   '밝혔습니다'],
#  ['다만',
#   '부산과',
#   '서울에',
#   '이어',
#   '경기도까지는',
#   '수장',
#   '공백',
#   '사태가',
#   '오지',
#   '않았다는',
#   '점은',
#   '다행이라고',
#   '말했는데요'],
#  ['만약',
#   '이',
#   '지사가',
#   '자리를',
#   '잃게',
#   '됐더라면',
#   '통합당이',
#   '내년',
#   '4월',
#   '보궐선거에서',
#   '정부',
#   '심판론을',
#   '넘어',
#   '정권',
#   '교체론까지',
#   '몰아갈',
#   '것이란',
#   '전망도',
#   '나왔습니다'],
#  ['경기',
#   '지사직은',
#   '빠졌지만',
#   '내년',
#   '보궐선거는',
#   '서울과',
#   '부산시장을',
#   '두고',
#   '사실상',
#   '대선',
#   '전초전으로',
#   '치러집니다'],
#  ['민주당은', '당장', '후보를', '낼지', '말지부터', '고민에', '빠진', '모습인데요'],
#  ['반면',
#   '통합당은',
#   '서울시장과',
#   '부산시장',
#   '보궐선거에',
#   '낙관적인',
#   '측면이',
#   '있다고',
#   '말하며',
#   '강한',
#   '자신감을',
#   '드러내고',
#   '있습니다'],
#  ['지금까지', '국회에서', '전해드렸습니다'],
#  ['정치권', '반응을', '알아봤습니다'],
#  ['앞으로의',
#   '이재명',
#   '지사의',
#   '정치',
#   '인생에',
#   '대해서도',
#   '짚어보지',
#   '않을',
#   '수가',
#   '없는데',
#   '정치권이',
#   '이번',
#   '선고',
#   '결과를',
#   '예의주시한',
#   '이유가',
#   '있을',
#   '겁니다'],
#  ['아무래도', '여권의', '유력한', '대권주자이기', '때문', '아니겠습니까'],
#  ['그렇죠'],
#  ['이재명', '지사는', '여권', '잠재주자', '중에서', '2위를', '달리고', '있고요'],
#  ['상당히', '지지세가', '급상승세를', '그리고', '있는', '상황입니다'],
#  ['그리고',
#   '여기다가',
#   '박원순',
#   '시장의',
#   '우리가',
#   '전혀',
#   '예상치',
#   '못한',
#   '극단적인',
#   '선택',
#   '이런',
#   '것',
#   '때문에',
#   '여권의',
#   '잠재주자들이',
#   '상당히',
#   '한',
#   '명',
#   '한',
#   '명씩',
#   '사라진',
#   '상황에서',
#   '만약에',
#   '이재명',
#   '지사까지',
#   '낙마했을',
#   '경우에',
#   '내년',
#   '민주당',
#   '내에서의',
#   '대권',
#   '경선',
#   '자체가',
#   '상당히',
#   '어떻게',
#   '보면',
#   '이낙연',
#   '주자',
#   '혼자의',
#   '홀로경선이',
#   '될',
#   '가능성이',
#   '높았다'],
#  ['그렇다고', '한다면', '흥행에도', '찬물을', '끼얹을', '수밖에', '없었던', '상황'],
#  ['그리고',
#   '께서도',
#   '리포트를',
#   '했지만',
#   '민주당',
#   '입장에서도',
#   '상당히',
#   '집권여당',
#   '입장에서도',
#   '안도의',
#   '한숨을',
#   '내쉴',
#   '수밖에',
#   '없다'],
#  ['부산에', '이어서', '서울까지'],
#  ['그리고',
#   '여기다',
#   '경기지사까지',
#   '낙마했을',
#   '경우에는',
#   '집권여당으로서의',
#   '책임도',
#   '있지만',
#   '그리고',
#   '내년',
#   '보궐선거에서',
#   '전국',
#   '3개의',
#   '가장',
#   '큰',
#   '광역단체에서의',
#   '선거가',
#   '이루어지는',
#   '상황에서',
#   '상당한',
#   '부담을',
#   '가질',
#   '수밖에',
#   '없었을',
#   '것인데',
#   '이러한',
#   '부분을',
#   '모면할',
#   '수',
#   '있다'],
#  ['아무래도', '무엇보다', '이번', '결정에서', '가장', '반길', '사람은', '이재명', '지사겠죠'],
#  ['이재명',
#   '지사는',
#   '사실',
#   '우리',
#   '정치권에서',
#   '입지전적인',
#   '인물로',
#   '알려져',
#   '있습니다마는',
#   '여기에다',
#   '하나',
#   '더',
#   '이미지를',
#   '추가한',
#   '것',
#   '같아요'],
#  ['오뚝이', '이미지까지'],
#  ['사실',
#   '이재명',
#   '지사가',
#   '여기까지',
#   '오는',
#   '과정에서',
#   '여러',
#   '가지',
#   '정치적',
#   '고난을',
#   '겪지',
#   '않았습니까'],
#  ['그리고',
#   '특히',
#   '지난',
#   '경기지사',
#   '선거와',
#   '관련해서',
#   '자신에게',
#   '주어졌던',
#   '상당한',
#   '걸림돌',
#   '중에',
#   '크게',
#   '두',
#   '가지가',
#   '있었는데',
#   '첫',
#   '번째가',
#   '여배우',
#   '스캔들'],
#  ['여배우',
#   '스캔들은',
#   '일단',
#   '무혐의가',
#   '되면서',
#   '경찰',
#   '단계에서',
#   '끝났습니다마는',
#   '두',
#   '번째',
#   '남은',
#   '것이',
#   '바로',
#   '친형',
#   '강제입원과',
#   '관련된',
#   '논란이었는데',
#   '이',
#   '부분도',
#   '지금',
#   '대법원에서',
#   '완전하게',
#   '클리어하게',
#   '정리됨으로써',
#   '본인',
#   '입장에서는',
#   '정치적',
#   '추세가',
#   '완전히',
#   '풀렸다'],
#  ['그렇다고',
#   '한다면',
#   '급상승을',
#   '그리고',
#   '있는',
#   '지지율에',
#   '그리고',
#   '또',
#   '변화된',
#   '여권의',
#   '구도',
#   '차기',
#   '대권구도',
#   '자체가',
#   '상당히',
#   '자기에게',
#   '유리한',
#   '쪽으로',
#   '진행될',
#   '수',
#   '있다'],
#  ['그렇다는',
#   '측면에서',
#   '본다면',
#   '이재명',
#   '지사',
#   '입장에서는',
#   '상당히',
#   '이제는',
#   '큰',
#   '날개를',
#   '펴면서',
#   '웅비의',
#   '한',
#   '순간을',
#   '맞이할',
#   '수도',
#   '있다는',
#   '전망도',
#   '나올',
#   '수',
#   '있는',
#   '상황인',
#   '것',
#   '같습니다'],
#  ['정치권도',
#   '숨',
#   '가쁘게',
#   '여러',
#   '판단을',
#   '내릴',
#   '것',
#   '같은데',
#   '오늘',
#   '선고와',
#   '관련해서',
#   '이재명',
#   '경기도지사의',
#   '변호인측',
#   '입장이',
#   '조금',
#   '전',
#   '들어왔습니다'],
#  ['직접', '들어보겠습니다'],
#  ['지금까지',
#   '이재명',
#   '경기도지사',
#   '변호인',
#   '측의',
#   '오늘',
#   '대법원',
#   '선고',
#   '결과에',
#   '대한',
#   '입장',
#   '들었습니다'],
#  ['그럼', '지금부터', '차근차근', '선고', '취지에', '대해서', '전문가와', '함께', '들어보도록', '하겠습니다'],
#  ['변호사님',
#   '오늘',
#   '무죄',
#   '취지로',
#   '사건을',
#   '파기환송한',
#   '것이지',
#   '않습니까',
#   '허위사실공표',
#   '부분에',
#   '대해서'],
#  ['저희도', '같이', '함께', '생중계로', '들었는데', '핵심은', '이거였던', '것', '같아요'],
#  ['후보자',
#   '토론회',
#   '과정에서',
#   '즉흥적인',
#   '진행으로',
#   '명확성에',
#   '한계가',
#   '있고',
#   '토론의',
#   '자유를',
#   '보장해야',
#   '된다',
#   '이런',
#   '취지였던',
#   '것',
#   '같은데',
#   '구체적으로',
#   '내용을',
#   '설명해',
#   '주시죠'],
#  ['전체적인', '것은', '그런', '취지였고요'],
#  ['일단', '후보자', '토론회', '방송', '후보자', '토론회는', '굉장히', '시간적', '제약이', '있잖아요'],
#  ['1분이면', '1분', '답할', '시간을', '그렇게', '주고', '굉장히', '숨가쁘게', '돌아가죠'],
#  ['그래서',
#   '여러',
#   '가지',
#   '제약이',
#   '있고',
#   '그다음에',
#   '사실',
#   '방송',
#   '토론을',
#   '하다',
#   '보면',
#   '준비된',
#   '원고에서',
#   '할',
#   '수가',
#   '없어요'],
#  ['그래서',
#   '굉장히',
#   '즉흥적인',
#   '면이',
#   '있는데',
#   '하다',
#   '보면',
#   '표현이',
#   '명확하지',
#   '않은',
#   '경우도',
#   '있고요'],
#  ['또',
#   '자신의',
#   '처한',
#   '입장을',
#   '어떻게',
#   '보면',
#   '변호하는',
#   '그런',
#   '상황이',
#   '될',
#   '수',
#   '있지',
#   '않습니까'],
#  ['그래서', '대법원에서는', '그런', '것', '같아요'],
#  ['어떠한',
#   '표현을',
#   '부정확하게',
#   '또',
#   '아니면',
#   '바람직하게',
#   '표현했다고',
#   '해서',
#   '이것',
#   '자체를',
#   '법적으로',
#   '처벌하는',
#   '것',
#   '자체는',
#   '방송토론이랄지',
#   '아니면',
#   '선거운동을',
#   '굉장히',
#   '제약하게',
#   '된다'],
#  ['그러면', '궁극적으로', '말하자면', '선거운동', '자체의', '본질을', '침해하는', '것이', '아니냐'],
#  ['그런', '대법원의', '판결', '이유', '같고요'],
#  ['그래서',
#   '결론적으로',
#   '이야기하면',
#   '어떤',
#   '의도적으로',
#   '적극적으로',
#   '왜곡했다거나',
#   '의도적으로',
#   '했다면',
#   '모르겠지만',
#   '해명하는',
#   '차원에서',
#   '했다고',
#   '한다면',
#   '이건',
#   '허위사실공표로',
#   '볼',
#   '수',
#   '없다'],
#  ['그래서', '공표', '자체를', '약간', '적극적', '의미로', '해석하는', '겁니다'],
#  ['설사',
#   '일부에',
#   '있어서',
#   '사실이',
#   '다르다',
#   '하더라도',
#   '해명하는',
#   '과정에서',
#   '거기에',
#   '대해서',
#   '굉장히',
#   '소극적으로',
#   '대답을',
#   '했다고',
#   '하면',
#   '공표라고',
#   '볼',
#   '수',
#   '없다',
#   '이렇게',
#   '보는',
#   '것',
#   '같고요'],
#  ['물론',
#   '이전에도',
#   '유사한',
#   '대법원',
#   '판결이',
#   '있지만',
#   '이번',
#   '판결',
#   '자체는',
#   '전원합의체에서',
#   '했다는',
#   '의미가',
#   '있고요'],
#  ['사실', '허위사실공표와', '관련해서는', '굉장히', '허위사실공표', '이게', '추상적인', '개념이거든요'],
#  ['그렇지만',
#   '오늘',
#   '전원합의체',
#   '판결에서',
#   '허위사실과',
#   '관련된',
#   '한계',
#   '특히',
#   '방송토론회에서의',
#   '한계하고',
#   '공표의',
#   '의미',
#   '자체가',
#   '상당히',
#   '적극성을',
#   '띄어야',
#   '한다',
#   '그런',
#   '의미로',
#   '선고를',
#   '했기',
#   '때문에',
#   '향후에',
#   '있어서',
#   '허위사실공표와',
#   '관련된',
#   '부분이',
#   '상당',
#   '부분',
#   '정리가',
#   '됐다고',
#   '봐요'],
#  ['그래서',
#   '무자비',
#   '고소고발을',
#   '일삼는다랄지',
#   '아니면',
#   '지금',
#   '이재명',
#   '지사에',
#   '관한',
#   '판결도',
#   '1심에서',
#   '무죄',
#   '2심에서',
#   '유죄가',
#   '나왔단',
#   '말이에요'],
#  ['그러니까',
#   '어떻게',
#   '보면',
#   '법을',
#   '전문적으로',
#   '하는',
#   '판사',
#   '자체도',
#   '굉장히',
#   '이',
#   '부분에',
#   '대해서',
#   '다른',
#   '시각을',
#   '가지고',
#   '있었잖아요'],
#  ['그런데',
#   '오늘',
#   '전원합의체',
#   '판결이',
#   '그',
#   '부분에서',
#   '상당히',
#   '명확하게',
#   '해석해',
#   '주었다',
#   '이렇게',
#   '판단해',
#   '볼',
#   '수가',
#   '있습니다'],
#  ['이후', '절차에', '대해서도', '한번', '살펴보겠습니다'],
#  ['앞서',
#   '간단하게',
#   '말씀하시기는',
#   '했는데',
#   '오늘',
#   '대법원은',
#   '원심을',
#   '무죄',
#   '취지로',
#   '어떻게',
#   '보면',
#   '파기하고',
#   '사건을',
#   '수원고등법원으로',
#   '돌려보냈습니다'],
#  ['결국',
#   '수원고법에서',
#   '파기환송심이',
#   '진행될',
#   '예정인데',
#   '대법원의',
#   '선고결과에',
#   '귀속되니까',
#   '무죄',
#   '취지의',
#   '판결이',
#   '나올',
#   '가능성이',
#   '높은',
#   '거죠',
#   '결국은'],
#  ['그렇죠'],
#  ['그리고', '파기환송심', '재판이', '오래', '걸리지', '않을', '거예요'],
#  ['왜냐하면', '이', '사건이', '2019년부터', '시작됐잖아요'],
#  ['그리고',
#   '1심과',
#   '2심을',
#   '통해서',
#   '엄청나게',
#   '치열한',
#   '공방을',
#   '했고',
#   '결국',
#   '대법원',
#   '판결까지',
#   '왔는데',
#   '증거랄지',
#   '사실관계는',
#   '거의',
#   '다',
#   '명확하게',
#   '정리가',
#   '됐다'],
#  ['또',
#   '그',
#   '부분에',
#   '대해서도',
#   '사실은',
#   '검찰에서',
#   '뭔가',
#   '이의제기를',
#   '해서',
#   '새로운',
#   '증거를',
#   '낼',
#   '수',
#   '있는',
#   '것들이',
#   '없어요'],
#  ['그리고', '지금', '대법원의', '판단', '자체는', '법률적', '해석에', '관한', '판단입니다'],
#  ['법률적',
#   '해석을',
#   '검찰측에서',
#   '다르게',
#   '한다고',
#   '해도',
#   '이걸',
#   '어떻게',
#   '보면',
#   '뒤집을',
#   '수',
#   '없거든요'],
#  ['그러면',
#   '다른',
#   '파기환송심',
#   '이재용',
#   '부회장이랄지',
#   '아니면',
#   '최서원',
#   '씨',
#   '판결',
#   '박근혜',
#   '전',
#   '대통령에',
#   '대한',
#   '파기환송과는',
#   '다르게',
#   '파기환송심이',
#   '수원고등에서',
#   '이루어지게',
#   '되는데',
#   '그',
#   '절차는',
#   '상당히',
#   '신속하게',
#   '진행될',
#   '가능성이',
#   '크다'],
#  ['왜냐하면', '법률적', '해석에', '관해서만', '정리를', '하면', '되니까요'],
#  ['그러면',
#   '결국',
#   '검찰이',
#   '재상고의',
#   '대상이',
#   '되지만',
#   '다른',
#   '사건에',
#   '비해서는',
#   '시간적인',
#   '것은',
#   '많이',
#   '걸리지',
#   '않는다'],
#  ['그러면',
#   '물론',
#   '오늘',
#   '전원합의체',
#   '판결로',
#   '이재명',
#   '지사가',
#   '완전히',
#   '자유로워졌다고',
#   '볼',
#   '수',
#   '있는',
#   '거죠'],
#  ['그렇지만',
#   '향후',
#   '대법원까지',
#   '다시',
#   '재상고된다',
#   '하더라도',
#   '이재명',
#   '지사가',
#   '정치활동을',
#   '하는',
#   '데는',
#   '아무런',
#   '제약이',
#   '없다',
#   '이렇게',
#   '보면',
#   '됩니다'],
#  ['최종',
#   '결론이',
#   '나올',
#   '때까지',
#   '시간은',
#   '오래',
#   '걸리지',
#   '않을',
#   '것이다라는',
#   '말씀을',
#   '해',
#   '주셨고요'],
#  ['정치권', '파장에', '대해서도', '계속', '얘기를', '나눠보겠습니다'],
#  ['앞서',
#   '교수님께서',
#   '말씀해',
#   '주신',
#   '것처럼',
#   '최근',
#   '이',
#   '지사의',
#   '지지도가',
#   '많이',
#   '오르는',
#   '모습이었는데',
#   '이낙연',
#   '의원에',
#   '대해서도',
#   '말씀을',
#   '해',
#   '주셨고요'],
#  ['이낙연', '의원과', '이재명', '지사'],
#  ['그럼', '지지도나', '이런', '게', '어떻게', '예상이', '될까요'],
#  ['일단',
#   '이재명',
#   '지사가',
#   '급상승세의',
#   '지지율을',
#   '보인',
#   '이유가',
#   '이번',
#   '코로나',
#   '사태와',
#   '관련해서',
#   '상당한',
#   '나름대로의',
#   '정치적',
#   '순발력을',
#   '통해서',
#   '상당히',
#   '국민들에게',
#   '다가가는',
#   '행정가의',
#   '모습을',
#   '보였다는',
#   '겁니다'],
#  ['예를', '들면', '코로나에', '대해서', '신천지에', '대한', '강제명령', '이런', '부분들'],
#  ['그리고',
#   '코로나',
#   '사태에서',
#   '비롯된',
#   '여러',
#   '가지',
#   '경제적인',
#   '어려움들',
#   '때문에',
#   '재난에',
#   '대한',
#   '기본소득을',
#   '주장하면서',
#   '사실상',
#   '재난지원금이',
#   '100',
#   '국민들에게',
#   '다',
#   '지급되는',
#   '데',
#   '어떻게',
#   '보면',
#   '물꼬를',
#   '튼',
#   '측면'],
#  ['그리고',
#   '그에',
#   '이어서',
#   '지금은',
#   '기본소득에',
#   '대한',
#   '이야기까지',
#   '이야기하면서',
#   '상당히',
#   '여러',
#   '가지',
#   '국정',
#   '현안에',
#   '대해서',
#   '아젠다를',
#   '주도하는',
#   '모습을',
#   '보이고',
#   '있다는',
#   '겁니다'],
#  ['그러한',
#   '상황에서',
#   '사실',
#   '어떻게',
#   '보면',
#   '정치적인',
#   '족쇄였던',
#   '지난',
#   '경기지사',
#   '선거',
#   '때의',
#   '법률적',
#   '문제가',
#   '완전히',
#   '해소가',
#   '되면',
#   '이제는',
#   '걸림돌이',
#   '사라진',
#   '것',
#   '아니겠습니까'],
#  ['그렇다고', '한다면', '본인의', '이러한', '정치적인', '공간이', '넓어진', '측면'],
#  ['그리고',
#   '상승세에',
#   '있는',
#   '지지율을',
#   '바탕으로',
#   '해서',
#   '아무래도',
#   '좀',
#   '더',
#   '공격적인',
#   '행보를',
#   '할',
#   '가능성이',
#   '높다'],
#  ['물론', '대법원', '판결이', '나오기', '전에는', '이런', '이야기도', '했습니다'],
#  ['자신의',
#   '향후',
#   '정치',
#   '역점과',
#   '관련해서',
#   '대선',
#   '도전에',
#   '대해서는',
#   '상당히',
#   '조심스러운',
#   '태도를',
#   '보였어요'],
#  ['지금',
#   '내',
#   '목이',
#   '날아가느냐',
#   '이',
#   '상황인데',
#   '그렇기',
#   '때문에',
#   '대선보다는',
#   '경기도지사',
#   '재선에',
#   '방점을',
#   '두는',
#   '듯한',
#   '모습을',
#   '보이기는',
#   '했습니다마는',
#   '이제는',
#   '상황이',
#   '완전히',
#   '달라졌거든요'],
#  ['그렇다고',
#   '한다면',
#   '본인',
#   '입장에서',
#   '좀',
#   '더',
#   '공격적인',
#   '상당히',
#   '적극적인',
#   '행보를',
#   '하지',
#   '않을까'],
#  ['사실',
#   '벌써',
#   '이번',
#   '코로나',
#   '사태',
#   '직후에',
#   '본인이',
#   '공격적인',
#   '모습을',
#   '보이고',
#   '있는',
#   '것',
#   '중',
#   '하나가',
#   '예를',
#   '들면',
#   '친문계',
#   '인사를',
#   '영입했고요'],
#  ['그리고',
#   '또',
#   '이번',
#   '대북전단',
#   '사건',
#   '관련해서',
#   '통일부가',
#   '주춤주춤하고',
#   '있을',
#   '때',
#   '이',
#   '부분도',
#   '적극적으로',
#   '뭔가',
#   '해서',
#   '예를',
#   '들면',
#   '여권',
#   '지지층으로부터',
#   '강한',
#   '결집을',
#   '받아내는',
#   '그런',
#   '모습들이',
#   '보였거든요'],
#  ['그렇다고',
#   '해서',
#   '그러면',
#   '모든',
#   '것이',
#   '앞으로',
#   '다',
#   '전도유망하게',
#   '무조건',
#   '갈',
#   '수',
#   '있느냐'],
#  ['꼭', '그렇지도', '않을', '겁니다'],
#  ['왜냐하면',
#   '사실',
#   '이재명',
#   '지사가',
#   '법률적으로는',
#   '클리어됐지만',
#   '아직까지도',
#   '강력한',
#   '친문',
#   '지지층들과의',
#   '정치적',
#   '앙금은',
#   '그대로',
#   '남아',
#   '있다는',
#   '겁니다'],
#  ['과거', '경기지사', '사건', '때', '여러', '가지', '논란들이', '많지', '않았습니까'],
#  ['그때',
#   '친문',
#   '세력들과',
#   '이재명',
#   '지사와의',
#   '정치적인',
#   '갈등들을',
#   '과연',
#   '얼마만큼',
#   '본인',
#   '스스로가',
#   '털고',
#   '화해하고',
#   '나갈',
#   '수',
#   '있느냐'],
#  ['그리고', '또', '하나는', '이번', '전당대회가', '8월에', '있지', '않습니까'],
#  ['8월달',
#   '전당대회',
#   '아마도',
#   '이낙연',
#   '의원이',
#   '강력한',
#   '당권주자로서',
#   '급부상하고',
#   '있는데',
#   '이낙연',
#   '지사가',
#   '물론',
#   '내년',
#   '3월까지로',
#   '한정돼있습니다마는',
#   '당권을',
#   '장악해서',
#   '예를',
#   '들어서',
#   '당내',
#   '조직을',
#   '확보했을',
#   '경우에는',
#   '내년',
#   '경선',
#   '자체가',
#   '아무래도',
#   '당내',
#   '조직에서',
#   '열세인',
#   '이재명',
#   '지사가',
#   '감당하기는',
#   '부담스러울',
#   '수',
#   '있다',
#   '그런',
#   '전망이',
#   '있습니다마는',
#   '모르겠습니다'],
#  ['일단',
#   '본인이',
#   '여러',
#   '가지를',
#   '생각해서',
#   '아마',
#   '정책적',
#   '행보는',
#   '적극적으로',
#   '할',
#   '가능성이',
#   '저는',
#   '높다고',
#   '봅니다'],
#  ['통합당의', '셈법도', '복잡해질', '것', '같은데', '어떻습니까'],
#  ['그렇죠',
#   '통합당',
#   '입장에서는',
#   '사실',
#   '이번',
#   '판결에',
#   '대해서는',
#   '상당히',
#   '유감의',
#   '뜻을',
#   '표하고',
#   '있습니다마는',
#   '무엇보다도',
#   '이재명',
#   '지사가',
#   '이번에',
#   '대권주자로',
#   '다시',
#   '살아났다는',
#   '측면을',
#   '가장',
#   '위협적으로',
#   '느끼지',
#   '않을까',
#   '하는',
#   '생각이',
#   '듭니다'],
#  ['앞서',
#   '제가',
#   '말씀드린',
#   '대로',
#   '이재명',
#   '지사가',
#   '만에',
#   '하나',
#   '낙마하는',
#   '경우가',
#   '됐다고',
#   '한다면',
#   '일단',
#   '여당의',
#   '경선',
#   '자체가',
#   '상당히',
#   '흥행적',
#   '요소가',
#   '사라질',
#   '가능성이',
#   '높다'],
#  ['그렇다고',
#   '한다면',
#   '이낙연',
#   '의원이',
#   '단독으로',
#   '만약에',
#   '추대됐을',
#   '경우에는',
#   '본선에',
#   '쉽게',
#   '올라갈',
#   '수',
#   '있다고',
#   '볼',
#   '수',
#   '있지만',
#   '그러나',
#   '당내',
#   '경선이',
#   '치열해지면',
#   '치열해질수록',
#   '누가',
#   '되든지',
#   '간에',
#   '본선',
#   '후보가',
#   '상당한',
#   '경쟁력을',
#   '가질',
#   '수',
#   '있다'],
#  ['그런',
#   '측면에서',
#   '본다고',
#   '하면',
#   '미래통합당',
#   '입장에서도',
#   '차기',
#   '대선에서',
#   '내세울',
#   '수',
#   '있는',
#   '후보를',
#   '상당히',
#   '좀',
#   '더',
#   '엄정하게',
#   '선임할',
#   '수밖에',
#   '없는',
#   '상황이다'],
#  ['그러나',
#   '당장',
#   '우리가',
#   '알다시피',
#   '미래통합당에서',
#   '차기',
#   '대선주자와',
#   '관련해서',
#   '풀에',
#   '한계가',
#   '있다'],
#  ['그런',
#   '측면에서',
#   '새로운',
#   '인물',
#   '새로운',
#   '시대정신을',
#   '가진',
#   '사람을',
#   '발굴해내야',
#   '되는',
#   '그런',
#   '정치적',
#   '과제가',
#   '훨씬',
#   '더',
#   '무거워진',
#   '것이',
#   '아닐까',
#   '하는',
#   '생각이',
#   '듭니다'],
#  ['이번',
#   '사건은',
#   '다수',
#   '의견을',
#   '따르는',
#   '전원합의체',
#   '판단에',
#   '따라서',
#   '원심의',
#   '유죄',
#   '선고',
#   '부분이',
#   '무죄',
#   '취지로',
#   '파기환송됐습니다'],
#  ['조금', '전에', '열렸던', '대법원', '선고', '핵심', '내용을', '다시', '한', '번', '들어보시겠습니다'],
#  ['대법원장의', '오늘', '주요', '선고', '취지에', '대해서', '다시', '한', '번', '들었습니다'],
#  ['변호사님',
#   '앞서',
#   '계속',
#   '말씀드리고',
#   '있는데',
#   '오늘',
#   '대법원',
#   '선고도',
#   '다수의견과',
#   '소수의견이',
#   '갈렸지',
#   '않습니까'],
#  ['그런데',
#   '원래',
#   '이게',
#   '대법원',
#   '대법관들',
#   '소부에',
#   '회부가',
#   '됐었는데',
#   '소부에서는',
#   '결국',
#   '만장일치로',
#   '의견일치를',
#   '봐야',
#   '되는데',
#   '의견일치가',
#   '안',
#   '돼서',
#   '결국',
#   '전원합의체로',
#   '넘어간',
#   '거잖아요'],
#  ['그만큼', '대법관들', '사이에서도', '어느', '정도', '이견차가', '있었다고', '봐야겠습니까', '어떻겠습니까'],
#  ['일단', '소부는', '대법관이', '4명으로', '구성되어', '있습니다'],
#  ['그래서', '여기서', '만장일치가', '안', '되면', '전원합의체로', '넘기는데', '회부한다고', '하죠'],
#  ['그런데', '지금', '만장일치가', '됐는지', '안', '됐는지에', '대해서는', '사실', '정확하지', '않아요'],
#  ['왜냐하면', '만장일치가', '안', '됐을', '때', '전원합의체에', '회부할', '수도', '있고요'],
#  ['아니면',
#   '이처럼',
#   '굉장히',
#   '사회적',
#   '이목을',
#   '끄는',
#   '사건에',
#   '대해서는',
#   '사실',
#   '4명의',
#   '법관이',
#   '하는',
#   '것',
#   '자체는',
#   '그렇게',
#   '결정하는',
#   '것은',
#   '문제가',
#   '있을',
#   '수',
#   '있기',
#   '때문에',
#   '전원합의체에',
#   '회부해서',
#   '이걸',
#   '명확하게',
#   '판결하려는',
#   '그런',
#   '의도가',
#   '있을',
#   '수',
#   '있기',
#   '때문에',
#   '소부에서',
#   '만장일치가',
#   '안',
#   '됐을',
#   '수도',
#   '있고요'],
#  ['아니면',
#   '만장일치가',
#   '됐다',
#   '하더라도',
#   '전원합의체로',
#   '회부될',
#   '수',
#   '있는데',
#   '저는',
#   '개인적',
#   '의견으로',
#   '볼',
#   '때',
#   '아마',
#   '만장일치가',
#   '안',
#   '나왔던',
#   '것',
#   '같아요'],
#  ['그리고',
#   '주심',
#   '판사였던',
#   '노정희',
#   '주심이',
#   '이전에도',
#   '이와',
#   '굉장히',
#   '유사한',
#   '춘천',
#   '사건이',
#   '하나',
#   '있었거든요'],
#  ['그때도',
#   '지금',
#   '판결',
#   '이유와',
#   '같은',
#   '똑같은',
#   '이유로',
#   '무죄',
#   '취지의',
#   '파기환송을',
#   '한',
#   '경우가',
#   '있거든요'],
#  ['그래서',
#   '저는',
#   '개인적으로',
#   '볼',
#   '때',
#   '아마',
#   '주심',
#   '판사의',
#   '입장은',
#   '굉장히',
#   '파기환송의',
#   '확고한',
#   '의지를',
#   '가지고',
#   '있을',
#   '것이다',
#   '그렇게',
#   '봤었고',
#   '그런다고',
#   '한다면',
#   '결과적으로',
#   '오늘',
#   '보니까',
#   '소수',
#   '의견이',
#   '다섯',
#   '분이고',
#   '그다음에',
#   '다수가',
#   '일곱',
#   '분이었거든요'],
#  ['그러니까', '법관', '인원수에서', '찬성과', '반대의', '차이가', '그렇게', '크지', '않았어요'],
#  ['만약에',
#   '이중에',
#   '한',
#   '명만',
#   '다른',
#   '의견이',
#   '있었다고',
#   '한다면',
#   '판결이',
#   '뒤바뀔',
#   '수도',
#   '있는',
#   '그런',
#   '경우가',
#   '있었기',
#   '때문에'],
#  ['그렇지만',
#   '결과적으로',
#   '7명',
#   '이상이',
#   '다수',
#   '의견이',
#   '됐기',
#   '때문에',
#   '결국',
#   '이재명',
#   '지사는',
#   '살아날',
#   '수',
#   '있었다',
#   '이렇게',
#   '볼',
#   '수',
#   '있는',
#   '거죠'],
#  ['말씀하신',
#   '대로',
#   '이렇게',
#   '대법관',
#   '사이에서',
#   '그리고',
#   '우리',
#   '사회에서',
#   '이',
#   '사안을',
#   '바라보는',
#   '여러',
#   '시각이',
#   '있기',
#   '때문에',
#   '그리고',
#   '중요한',
#   '사안이기',
#   '때문에',
#   '대법원에서도',
#   '이례적이지',
#   '않습니까'],
#  ['이렇게', '선고', '결과를', '생중계하는', '게'],
#  ['박근혜', '전', '대통령', '국정농단', '사건', '이후에', '두', '번째인', '거잖아요', '이게'],
#  ['그렇죠'],
#  ['자치단체장으로는', '처음입니다', '이재명', '지사가'],
#  ['그래서',
#   '사실',
#   '선고에',
#   '대한',
#   '공개',
#   '그것에',
#   '대해서는',
#   '규정이',
#   '나온',
#   '건',
#   '오래되지',
#   '않았어요',
#   '대법원',
#   '자체에서'],
#  ['그런데',
#   '이재명',
#   '지사에',
#   '대해서',
#   '선고가',
#   '사실은',
#   '유죄',
#   '부분에',
#   '대한',
#   '공직선거법',
#   '위반',
#   '허위사실공표에',
#   '대해서',
#   '사실',
#   '법리가',
#   '그렇게',
#   '어려운',
#   '건',
#   '아닙니다'],
#  ['그러면', '대법원에서', '그냥', '선고하면', '되는데', '왜', '이걸', '공개했을까'],
#  ['그건',
#   '첫',
#   '번째',
#   '사회적',
#   '이목을',
#   '집중시키는',
#   '사건이라고',
#   '볼',
#   '수',
#   '있고',
#   '또',
#   '하나는',
#   '이게',
#   '너무',
#   '간단하게',
#   '선고할',
#   '것',
#   '같으면',
#   '전원합의체에',
#   '회부됐다',
#   '하더라도',
#   '공개',
#   '안',
#   '할',
#   '수도',
#   '있는',
#   '거거든요'],
#  ['그런데',
#   '허위사실공표죄에',
#   '관해서',
#   '대법원의',
#   '법리적인',
#   '것',
#   '그런',
#   '것들을',
#   '명확하게',
#   '국민에게',
#   '알리고',
#   '싶어',
#   '하는',
#   '그런',
#   '측면도',
#   '있지',
#   '않았을까'],
#  ['저는', '그렇게', '봅니다'],
#  ['오늘',
#   '이재명',
#   '지사는',
#   '대법원에',
#   '나오지',
#   '않았는데',
#   '대법원',
#   '판결',
#   '같은',
#   '경우는',
#   '굳이',
#   '안',
#   '나와도',
#   '되는',
#   '거죠'],
#  ['그렇죠',
#   '일반적인',
#   '형사사건은',
#   '1심이나',
#   '2심에서는',
#   '반드시',
#   '선고날',
#   '나와서',
#   '출석을',
#   '해야',
#   '합니다'],
#  ['그리고', '만약에', '출석을', '계속', '안', '하게', '되면', '영장발부를', '하게', '돼요'],
#  ['아니면', '피고인이', '없는', '상태에서', '선고를', '하죠'],
#  ['그러면', '대부분', '실형', '선고를', '하거든요'],
#  ['그렇지만',
#   '대법원',
#   '같은',
#   '경우는',
#   '실질적으로',
#   '심리',
#   '자체가',
#   '피고인이',
#   '법정에',
#   '출석해서',
#   '하는',
#   '심리가',
#   '아니고',
#   '서면심리거든요'],
#  ['그리고', '더군다나', '법률심이기', '때문에', '선고', '때', '피고인은', '출석하지', '않아도', '됩니다'],
#  ['이재명',
#   '지사는',
#   '사실',
#   '앞서',
#   '쟁점이',
#   '되는',
#   '허위사실공표죄에',
#   '대한',
#   '위헌법률심판제청신청서를',
#   '제출했고',
#   '또',
#   '대법',
#   '공개변론',
#   '신청도',
#   '했잖아요'],
#  ['그렇게', '되면', '이렇게', '적극적으로', '방어했다고', '볼', '수', '있겠죠'],
#  ['본인', '입장에서는', '엄청난', '일이죠'],
#  ['더구나',
#   '경기지사를',
#   '만약에',
#   '대법원에서',
#   '유죄가',
#   '확정돼',
#   '버리면',
#   '일단',
#   '향후',
#   '본인의',
#   '정치는',
#   '더',
#   '재기할',
#   '수',
#   '없는',
#   '상황일',
#   '뿐만',
#   '아니라',
#   '더군다나',
#   '5년간',
#   '또',
#   '피선거권이',
#   '박탈되고',
#   '또',
#   '지금',
#   '선거자금이',
#   '38억',
#   '정도가',
#   '보존됐거든요'],
#  ['그러면',
#   '그것도',
#   '사실은',
#   '다시',
#   '반환해야',
#   '하는',
#   '그런',
#   '입장이기',
#   '때문에',
#   '어찌',
#   '보면',
#   '본인',
#   '입장에서는',
#   '절대절명이고',
#   '아무튼',
#   '사력을',
#   '다해서',
#   '이',
#   '재판에',
#   '임할',
#   '수밖에',
#   '없는',
#   '그런',
#   '상황이었다고',
#   '봅니다'],
#  ['그래서', '할', '수', '있는', '방법은', '모두', '꺼냈다'],
#  ['그래서', '결국', '이러한', '것들이', '통하지', '않았나', '저는', '그런', '생각을', '합니다'],
#  ['그리고',
#   '법리적인',
#   '측면에서도',
#   '2심에서',
#   '유죄가',
#   '나왔지만',
#   '아마',
#   '변호사랄지',
#   '아니면',
#   '이재명',
#   '지사도',
#   '변호사',
#   '출신',
#   '아닙니까'],
#  ['굉장히', '많은', '숙고와', '공부를', '했을', '것이다'],
#  ['그래서', '오늘', '대법원', '판결을', '끌어냈다', '이렇게', '볼', '수도', '있는', '거죠'],
#  ['마지막으로', '교수님', '내년', '재보선은', '서울시와', '부산시', '두', '곳에서', '치러지는', '거죠'],
#  ['그렇죠'],
#  ['지금',
#   '아무래도',
#   '이번',
#   '경기도지사에',
#   '대한',
#   '재판',
#   '자체가',
#   '상당히',
#   '원심에',
#   '대한',
#   '파기환송으로',
#   '갔기',
#   '때문에',
#   '내년',
#   '경기도지사',
#   '선거는',
#   '없는',
#   '걸로',
#   '봐야',
#   '될',
#   '것',
#   '같고요'],
#  ['그럼에도',
#   '불구하고',
#   '내년',
#   '선거가',
#   '상당히',
#   '중요한',
#   '이유가',
#   '우리나라',
#   '제1',
#   '2도시에서의',
#   '단체장을',
#   '뽑는',
#   '선거',
#   '아닙니까'],
#  ['그럼',
#   '무엇보다도',
#   '지금',
#   '민주당',
#   '소속의',
#   '광역단체장들이',
#   '자신들의',
#   '여러',
#   '가지',
#   '귀책사유로',
#   '인해서',
#   '지금',
#   '현재',
#   '선거가',
#   '치러지는',
#   '상황이기',
#   '때문에',
#   '민주당',
#   '입장에서는',
#   '상당히',
#   '정치적',
#   '수세에',
#   '몰릴',
#   '수밖에',
#   '없다'],
#  ['그렇다고', '해서', '그러면', '귀책사유가', '있다고', '해서', '후보를', '내지', '않을', '것이냐'],
#  ['또', '그럴', '수도', '없다는', '이야기들을', '당', '내에서', '나온다는', '겁니다'],
#  ['물론',
#   '당헌에는',
#   '그렇게',
#   '규정되어',
#   '있지만',
#   '지금',
#   '내년',
#   '보궐선거가',
#   '그',
#   '후년에',
#   '있는',
#   '대통령',
#   '선거에',
#   '상당히',
#   '큰',
#   '영향을',
#   '줄',
#   '수밖에',
#   '없는',
#   '상황이다'],
#  ['그런',
#   '측면에서',
#   '보면',
#   '지금',
#   '경기도지사는',
#   '일단',
#   '살아남으로써',
#   '경기도지사는',
#   '빠졌지만',
#   '내년',
#   '4월',
#   '보궐선거는',
#   '상당한',
#   '정치적',
#   '의미가',
#   '계속적으로',
#   '이어질',
#   '수밖에',
#   '없는',
#   '상황인',
#   '것',
#   '같습니다'],
#  ['알겠습니다'],
#  ['이재명', '경기지사가', '오늘', '선고', '결과에', '회견을', '한다는', '소식도', '들어왔습니다'],
#  ['기자회견', '장면은', '이어지는', '뉴스에서', '전해', '드리도록', '하겠습니다'],
#  ['지금까지', '김광삼', '변호사', '차재원', '부산가톨릭대', '특임교수와', '함께', '이야기', '나눴습니다'],
#  ['오늘', '말씀', '고맙습니다']]

# %% [markdown]
# #### **Word2Vec 학습**
#
# gensim에서는 다음과 같이 Word2Vec을 지원한다.
#
# > `sentences` : 단어 토큰화된 문장
# > `size` : Projection Layer의 크기, 임베딩 벡터의 차원
# > `window` : 윈도우 크기
# > `min_count` : 단어의 최소 빈도 수, 이 이하의 빈도를 가지는 단어는 학습하지 않음
# > `workers` : 학습을 위한 프로세스 수
# > `sg` : 0일 경우 CBOW, 1일 경우 Skip-Gram

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=tokenList, size=100, window=5, min_count=1, workers=4, sg=0)

# %% [markdown]
# '선거'를 입력했을 때 의미가 유사한 단어들을 출력합니다.

# %%
model_result = model.wv.most_similar("선거")
model_result
# Out:
# [('뉴스에서', 0.338172972202301),
#  ('귀속이', 0.3328704535961151),
#  ('표현했다고', 0.33212876319885254),
#  ('저는', 0.3084290623664856),
#  ('결국은', 0.29316264390945435),
#  ('그렇죠', 0.28543901443481445),
#  ('말씀드린', 0.2808339595794678),
#  ('대선주자와', 0.27329280972480774),
#  ('지지층들과의', 0.26043033599853516),
#  ('전원합의체에', 0.25079941749572754)]

# %% [markdown]
# #### **Skip-Gram**
#
# 중심 단어를 통해 주변에 있는 단어들을 예측하는 방법이다.
# 소량의 학습 데이터에서도 잘 동작하며, 자주 사용하지 않는 희귀한 단어를 예측할 수 있다. 하지만 계산 비용이 크다는 문제점이 있다.
# 마찬가지로 중심 단어에 윈도우를 두고, 윈도우 내의 주변 단어의 임베딩 벡터를 예측한다.

# %%
model = Word2Vec(sentences=tokenList, size=100, window=5, min_count=1, workers=4, sg=1)

# %%
model_result = model.wv.most_similar("선거")
model_result
# Out:
# [('뉴스에서', 0.35526594519615173),
#  ('표현했다고', 0.3478245735168457),
#  ('귀속이', 0.34415918588638306),
#  ('저는', 0.33563393354415894),
#  ('그렇죠', 0.29303207993507385),
#  ('대선주자와', 0.292006254196167),
#  ('결국은', 0.29079103469848633),
#  ('말씀드린', 0.28423285484313965),
#  ('전원합의체에', 0.2752193212509155),
#  ('지지층들과의', 0.2710190713405609)]

# %% [markdown]
# 기사 본문 내용이 짧기 때문에, 모델을 학습하기에 corpus의 크기가 작다.
# 유사도 또한 상당히 낮다.
# 아래는 수집한 기사 100,000건들을 통해 corpus를 구성하고, Word2Vec 모델을 구축하는 내용이다.

# %%
media_list = os.listdir(ORIGIN_PATH)

result = []
forCount = []
for media in media_list:
    media_path = os.path.join(PREPROCESSED_PATH, media)
    article_list= os.listdir(media_path)

    for article in article_list:
        reader = RawTextReader(os.path.join(media_path, article)) 
        content = list(filter(None, reader))
        forCount += [token for sent in content for token in sent.split()]
        result += [sent.split() for sent in content]

# %%
print("전체 token의 개수 : {len}".format(len=len(forCount)))
print("중복되지 않은 token의 개수 : {len}".format(len=len(list(set(forCount)))))
# Out:
# 전체 token의 개수 : 22341223
# 중복되지 않은 token의 개수 : 1107954

# %%
model = Word2Vec(sentences=result, size=200, window=5, min_count=3, workers=4, sg=1)

# %%
model_result = model.wv.most_similar("선거")
model_result

# %%
model.wv.__getitem__('선거')

# %%
model.save("word2vec.model")
